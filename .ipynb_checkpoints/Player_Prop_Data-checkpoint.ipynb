# %% [markdown]
# # Accessing Odds API to gather Player Props data

# %%
import requests
import json
import pandas as pd
import re
import numpy as np
from datetime import datetime, timedelta
import os

# %%
api_key_1 = os.getenv('Sport_Game_Odd_Key') # for the sportsGame API
api_key_2 = os.getenv('Odds_API_Key') # For the odds API

# %%
header = {'x-api-key': api_key_1}

# %%
today = datetime.today()
tomorrow = today + timedelta(days = 1)
yesterday = today - timedelta(days = 1)

# %%
response = requests.get('https://api.sportsgameodds.com/v1/events', params={
    'leagueID': 'NBA',
    'marketOddsAvailable': 'true',
    'limit': 30,
    'startsAfter': today,
    'startsBefore': tomorrow
}, headers = header)

data = response.json()

# %%
data
# Out:
# {'success': True,
#  'data': [{'eventID': '95ME4GmUdK2nfurETCSN',
#    'sportID': 'BASKETBALL',
#    'leagueID': 'NBA',
#    'type': 'match',
#    'info': {'seasonWeek': 'NBA 24/25'},
#    'teams': {'home': {'statEntityID': 'home',
#      'names': {'nickname': 'Nets',
#       'short': 'BKN',
#       'location': 'Brooklyn',
#       'medium': 'Nets',
#       'long': 'Brooklyn Nets'},
#      'teamID': 'BROOKLYN_NETS_NBA',
#      'colors': {'primaryContrast': '#000000', 'primary': '#FFFFFF'}},
#     'away': {'statEntityID': 'away',
#      'names': {'nickname': 'Magic',
#       'short': 'ORL',
#       'location': 'Orlando',
#       'medium': 'Magic',
#       'long': 'Orlando Magic'},
#      'teamID': 'ORLANDO_MAGIC_NBA',
#      'colors': {'secondary': '#C4CED3',
#       'primaryContrast': '#000000',
#       'secondaryContrast': '#007DC5',
#       'primary': '#007DC5'}}},
#    'players': {'GOGA_BITADZE_ORLANDO_MAGIC_NBA': {'playerID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'firstName': 'Goga',
#      'lastName': 'Bitadze',
#      'name': 'Goga Bitadze',
#      'teamID': 'ORLANDO_MAGIC_NBA'},
#     'CAMERON_JOHNSON_BROOKLYN_NETS_NBA': {'playerID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'firstName': 'Cameron',
#      'lastName': 'Johnson',
#      'name': 'Cameron Johnson',
#      'teamID': 'BROOKLYN_NETS_NBA'},
#     'BEN_SIMMONS_BROOKLYN_NETS_NBA': {'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'firstName': 'Ben',
#      'lastName': 'Simmons',
#      'name': 'Ben Simmons',
#      'teamID': 'BROOKLYN_NETS_NBA'},
#     'JALEN_SUGGS_ORLANDO_MAGIC_NBA': {'playerID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'firstName': 'Jalen',
#      'lastName': 'Suggs',
#      'name': 'Jalen Suggs',
#      'teamID': 'ORLANDO_MAGIC_NBA'},
#     'FRANZ_WAGNER_ORLANDO_MAGIC_NBA': {'playerID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'firstName': 'Franz',
#      'lastName': 'Wagner',
#      'name': 'Franz Wagner',
#      'teamID': 'ORLANDO_MAGIC_NBA'},
#     'DENNIS_SCHRODER_BROOKLYN_NETS_NBA': {'playerID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'firstName': 'Dennis',
#      'lastName': 'Schröder',
#      'name': 'Dennis Schroder',
#      'teamID': 'BROOKLYN_NETS_NBA'},
#     'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA': {'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'firstName': 'Wendell',
#      'lastName': 'Carter Jr.',
#      'name': 'Wendell Carter Jr.',
#      'teamID': 'ORLANDO_MAGIC_NBA'},
#     'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA': {'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'firstName': 'Jonathan',
#      'lastName': 'Isaac',
#      'name': 'Jonathan Isaac',
#      'teamID': 'ORLANDO_MAGIC_NBA'},
#     'ANTHONY_BLACK_ORLANDO_MAGIC_NBA': {'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'firstName': 'Anthony',
#      'lastName': 'Black',
#      'name': 'Anthony Black',
#      'teamID': 'ORLANDO_MAGIC_NBA'},
#     'MORITZ_WAGNER_ORLANDO_MAGIC_NBA': {'playerID': 'MORITZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'firstName': 'Moritz',
#      'lastName': 'Wagner',
#      'name': 'Moritz Wagner',
#      'teamID': 'ORLANDO_MAGIC_NBA'}},
#    'status': {'hardStart': True,
#     'started': False,
#     'delayed': False,
#     'completed': False,
#     'finalized': False,
#     'hasAnyOdds': True,
#     'ended': False,
#     'cancelled': False,
#     'startsAt': '2024-12-01T20:30:00.000Z',
#     'live': False,
#     'hasMarketOdds': True,
#     'anyOddsAvailable': True,
#     'marketOddsAvailable': True,
#     'oddsOverview': 'Magic favored by 6.5 points',
#     'displayLong': 'Upcoming'},
#    'odds': {'blocks+steals-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-under': {'oddID': 'blocks+steals-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-under',
#      'statID': 'blocks+steals',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'odds': '-120',
#      'bookOdds': '-140'},
#     'blocks+steals-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-under': {'oddID': 'blocks+steals-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-under',
#      'statID': 'blocks+steals',
#      'statEntityID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'bookOdds': '-170',
#      'odds': '-140'},
#     'doubleDouble-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-yn-no': {'oddID': 'doubleDouble-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-yn-no',
#      'statID': 'doubleDouble',
#      'statEntityID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'no',
#      'playerID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'bookOdds': '-999900',
#      'odds': '-1740',
#      'available': False},
#     'rebounds+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'rebounds+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'rebounds+assists',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '5.5',
#      'bookOdds': '-120',
#      'bookOverUnder': '5.5'},
#     'blocks+steals-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'blocks+steals-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'blocks+steals',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+110',
#      'overUnder': '2.5',
#      'bookOdds': '-105',
#      'bookOverUnder': '2.5'},
#     'points+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points+assists',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '10.5',
#      'bookOdds': '-115',
#      'bookOverUnder': '10.5'},
#     'blocks+steals-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'blocks+steals-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'blocks+steals',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-110',
#      'overUnder': '2.5',
#      'bookOverUnder': '2.5',
#      'bookOdds': '-130'},
#     'blocks-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'blocks-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'blocks',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'odds': '-180',
#      'bookOdds': '-225'},
#     'points+assists-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points+assists-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points+assists',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '10.5',
#      'overUnder': '10.5',
#      'bookOdds': '-130',
#      'odds': '-110'},
#     'blocks-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'blocks-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'blocks',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'bookOdds': '-105',
#      'odds': '+110'},
#     'points-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '6.5',
#      'overUnder': '6.5',
#      'bookOdds': '-110'},
#     'blocks-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-under': {'oddID': 'blocks-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-under',
#      'statID': 'blocks',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'bookOdds': '-115'},
#     'points-away-4q-ml-away': {'oddID': 'points-away-4q-ml-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '4q',
#      'betTypeID': 'ml',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '-135',
#      'odds': '-120'},
#     'steals-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'steals-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'steals',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'odds': '+115',
#      'bookOdds': '+100'},
#     'points-away-game-sp-away': {'oddID': 'points-away-game-sp-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': 'game',
#      'betTypeID': 'sp',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookSpread': '-6.5',
#      'bookOdds': '-110',
#      'spread': '-6.5'},
#     'points-home-game-ml-home': {'oddID': 'points-home-game-ml-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'game',
#      'betTypeID': 'ml',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+220',
#      'odds': '+235'},
#     'points-home-game-sp-home': {'oddID': 'points-home-game-sp-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'game',
#      'betTypeID': 'sp',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookSpread': '+6.5',
#      'spread': '+6.5',
#      'bookOdds': '-110'},
#     'doubleDouble-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-yn-no': {'oddID': 'doubleDouble-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-yn-no',
#      'statID': 'doubleDouble',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'no',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '-1200',
#      'odds': '-555'},
#     'doubleDouble-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-yn-yes': {'oddID': 'doubleDouble-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-yn-yes',
#      'statID': 'doubleDouble',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'yes',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+500',
#      'odds': '+555'},
#     'points+rebounds-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points+rebounds-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points+rebounds',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '16.5',
#      'bookOdds': '-125',
#      'bookOverUnder': '15.5',
#      'odds': '+100'},
#     'turnovers-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'turnovers-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'turnovers',
#      'statEntityID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '2.5',
#      'bookOverUnder': '2.5',
#      'odds': '+100',
#      'bookOdds': '-125'},
#     'assists-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'assists-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'assists',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'bookOdds': '-115'},
#     'steals-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'steals-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'steals',
#      'statEntityID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'bookOdds': '-125'},
#     'points+assists-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'points+assists-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'points+assists',
#      'statEntityID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '10.5',
#      'bookOdds': '-115',
#      'overUnder': '11'},
#     'rebounds-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'rebounds-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'rebounds',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '6.5',
#      'overUnder': '6.5',
#      'bookOdds': '-105',
#      'odds': '+100'},
#     'points+rebounds+assists-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'points+rebounds+assists-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'points+rebounds+assists',
#      'statEntityID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '27.5',
#      'overUnder': '27.5',
#      'bookOdds': '-105'},
#     'steals-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'steals-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'steals',
#      'statEntityID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '0.5',
#      'bookOdds': '-160',
#      'overUnder': '0.5',
#      'odds': '-130'},
#     'steals-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'steals-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'steals',
#      'statEntityID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '0.5',
#      'bookOdds': '+115',
#      'overUnder': '0.5',
#      'odds': '+130'},
#     'blocks+steals-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'blocks+steals-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'blocks+steals',
#      'statEntityID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '2.5',
#      'bookOverUnder': '2.5',
#      'odds': '-150',
#      'bookOdds': '-180'},
#     'blocks+steals-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'blocks+steals-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'blocks+steals',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'odds': '+120',
#      'bookOdds': '+105'},
#     'blocks+steals-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-ou-under': {'oddID': 'blocks+steals-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-ou-under',
#      'statID': 'blocks+steals',
#      'statEntityID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '1.5',
#      'overUnder': '1.5',
#      'odds': '-200',
#      'bookOdds': '-250'},
#     'points+assists-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'points+assists-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'points+assists',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '7.5',
#      'bookOverUnder': '7.5',
#      'bookOdds': '-130',
#      'odds': '-110'},
#     'points-home-4q-ml-home': {'oddID': 'points-home-4q-ml-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '4q',
#      'betTypeID': 'ml',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+120',
#      'bookOdds': '+110'},
#     'points+rebounds+assists-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'points+rebounds+assists-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'points+rebounds+assists',
#      'statEntityID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '24.5',
#      'overUnder': '24.5',
#      'bookOdds': '-120'},
#     'points-away-3q-sp-away': {'oddID': 'points-away-3q-sp-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '3q',
#      'betTypeID': 'sp',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookSpread': '-1.5',
#      'spread': '-1.5',
#      'odds': '+100',
#      'bookOdds': '-120'},
#     'points-all-2q-ou-over': {'oddID': 'points-all-2q-ou-over',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '2q',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '53.5',
#      'overUnder': '53.5',
#      'bookOdds': '-115'},
#     'doubleDouble-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-yn-yes': {'oddID': 'doubleDouble-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-yn-yes',
#      'statID': 'doubleDouble',
#      'statEntityID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'yes',
#      'playerID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'odds': '+1740',
#      'available': False,
#      'bookOdds': '+1400'},
#     'points-away-game-ml-away': {'oddID': 'points-away-game-ml-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': 'game',
#      'betTypeID': 'ml',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-235',
#      'bookOdds': '-270'},
#     'points-home-1h-ou-under': {'oddID': 'points-home-1h-ou-under',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '1h',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '51.5',
#      'bookOverUnder': '51.5',
#      'bookOdds': '-110'},
#     'points-all-2q-ou-under': {'oddID': 'points-all-2q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '2q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '53.5',
#      'overUnder': '53.5',
#      'bookOdds': '-115'},
#     'points-home-1q-ml-home': {'oddID': 'points-home-1q-ml-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '1q',
#      'betTypeID': 'ml',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+150',
#      'bookOdds': '+140'},
#     'points-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'points-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '17.5',
#      'overUnder': '17.5',
#      'odds': '+100',
#      'bookOdds': '-106'},
#     'points-all-4q-ou-over': {'oddID': 'points-all-4q-ou-over',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '4q',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '48.5',
#      'bookOverUnder': '48.5',
#      'bookOdds': '-114'},
#     'points-away-2h-ml-away': {'oddID': 'points-away-2h-ml-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2h',
#      'betTypeID': 'ml',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-155',
#      'bookOdds': '-180'},
#     'points-all-1h-ou-under': {'oddID': 'points-all-1h-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '1h',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '107',
#      'bookOdds': '-110',
#      'bookOverUnder': '107'},
#     'points-all-1h-ou-over': {'oddID': 'points-all-1h-ou-over',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '1h',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '107',
#      'bookOdds': '-110',
#      'bookOverUnder': '107'},
#     'points-all-1q-ou-under': {'oddID': 'points-all-1q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '1q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '53.5',
#      'overUnder': '53.5',
#      'bookOdds': '-110'},
#     'points-away-1q-ml-away': {'oddID': 'points-away-1q-ml-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '1q',
#      'betTypeID': 'ml',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-150',
#      'bookOdds': '-170'},
#     'points-away-2h-ou-under': {'oddID': 'points-away-2h-ou-under',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2h',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '51.5',
#      'overUnder': '51.5',
#      'bookOdds': '-110'},
#     'points-away-2h-ou-over': {'oddID': 'points-away-2h-ou-over',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2h',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '51.5',
#      'overUnder': '51.5',
#      'bookOdds': '-110'},
#     'points-home-game-ou-over': {'oddID': 'points-home-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '100.5',
#      'overUnder': '100',
#      'bookOdds': '-105'},
#     'points-home-1h-sp-home': {'oddID': 'points-home-1h-sp-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '1h',
#      'betTypeID': 'sp',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookSpread': '+3.5',
#      'bookOdds': '-110',
#      'spread': '+3.5'},
#     'points+rebounds-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'points+rebounds-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'points+rebounds',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '16.5',
#      'bookOverUnder': '15.5',
#      'odds': '+100',
#      'bookOdds': '-109'},
#     'points-away-game-ou-under': {'oddID': 'points-away-game-ou-under',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '106.5',
#      'bookOdds': '-110',
#      'overUnder': '106.5'},
#     'points-home-1h-ml-home': {'oddID': 'points-home-1h-ml-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '1h',
#      'betTypeID': 'ml',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+175',
#      'bookOdds': '+164'},
#     'assists-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'assists-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'assists',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '5.5',
#      'overUnder': '6',
#      'bookOdds': '-120'},
#     'rebounds-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'rebounds-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'rebounds',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '6.5',
#      'bookOverUnder': '6.5',
#      'odds': '+115',
#      'bookOdds': '+100'},
#     'points-home-3q-sp-home': {'oddID': 'points-home-3q-sp-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '3q',
#      'betTypeID': 'sp',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookSpread': '+1.5',
#      'spread': '+1.5',
#      'odds': '+100',
#      'bookOdds': '-110'},
#     'points-home-2h-ml-home': {'oddID': 'points-home-2h-ml-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '2h',
#      'betTypeID': 'ml',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+155',
#      'bookOdds': '+140'},
#     'points-all-4q-ou-under': {'oddID': 'points-all-4q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '4q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '48.5',
#      'bookOverUnder': '48.5',
#      'bookOdds': '-115'},
#     'points-home-4q-ou-over': {'oddID': 'points-home-4q-ou-over',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '4q',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '23.5',
#      'bookOverUnder': '23.5',
#      'odds': '+100',
#      'bookOdds': '-125'},
#     'threePointersMade-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-under': {'oddID': 'threePointersMade-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-under',
#      'statID': 'threePointersMade',
#      'statEntityID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '2.5',
#      'overUnder': '3',
#      'odds': '+100',
#      'bookOdds': '+100'},
#     'points-home-1q-sp-home': {'oddID': 'points-home-1q-sp-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '1q',
#      'betTypeID': 'sp',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'spread': '+2',
#      'bookSpread': '+2',
#      'bookOdds': '-115'},
#     'points+rebounds+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points+rebounds+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points+rebounds+assists',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '12.5',
#      'bookOdds': '-120',
#      'overUnder': '13.5',
#      'odds': '+120'},
#     'points+rebounds+assists-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points+rebounds+assists-JALEN_SUGGS_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points+rebounds+assists',
#      'statEntityID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'JALEN_SUGGS_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '24.5',
#      'overUnder': '24.5',
#      'bookOdds': '-110'},
#     'points+rebounds+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'points+rebounds+assists-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'points+rebounds+assists',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '12.5',
#      'bookOdds': '-110',
#      'overUnder': '13.5',
#      'odds': '-120'},
#     'points-home-2h-ou-under': {'oddID': 'points-home-2h-ou-under',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '2h',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '48',
#      'bookOdds': '+100',
#      'bookOverUnder': '47.5'},
#     'points-home-2h-ou-over': {'oddID': 'points-home-2h-ou-over',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '2h',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '48',
#      'bookOdds': '-120',
#      'bookOverUnder': '47.5'},
#     'points+rebounds-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'points+rebounds-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'points+rebounds',
#      'statEntityID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '21.5',
#      'overUnder': '21.5',
#      'bookOdds': '-110'},
#     'steals-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'steals-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'steals',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '0.5',
#      'overUnder': '0.5',
#      'bookOdds': '-160',
#      'odds': '-130'},
#     'threePointersMade-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'threePointersMade-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'threePointersMade',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'odds': '-120',
#      'bookOdds': '-141'},
#     'points-away-reg-ml3way-away': {'oddID': 'points-away-reg-ml3way-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': 'reg',
#      'betTypeID': 'ml3way',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '-255',
#      'odds': '-230'},
#     'points-home-reg-ml3way-home+draw': {'oddID': 'points-home-reg-ml3way-home+draw',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'reg',
#      'betTypeID': 'ml3way',
#      'sideID': 'home+draw',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+230'},
#     'points-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'points-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'points',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+100',
#      'bookOverUnder': '6.5',
#      'overUnder': '7.5',
#      'odds': '-125'},
#     'rebounds-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'rebounds-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'rebounds',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '5.5',
#      'overUnder': '5.5',
#      'bookOdds': '-109'},
#     'doubleDouble-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-yn-no': {'oddID': 'doubleDouble-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-yn-no',
#      'statID': 'doubleDouble',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'no',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '-3000',
#      'odds': '-725'},
#     'blocks-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'blocks-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'blocks',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'odds': '-175',
#      'bookOdds': '-220'},
#     'doubleDouble-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-yn-no': {'oddID': 'doubleDouble-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-yn-no',
#      'statID': 'doubleDouble',
#      'statEntityID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'no',
#      'playerID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '-700',
#      'odds': '-415'},
#     'turnovers-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'turnovers-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'turnovers',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+160',
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'bookOdds': '+140'},
#     'blocks+steals-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'blocks+steals-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'blocks+steals',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'odds': '-155',
#      'bookOdds': '-190'},
#     'doubleDouble-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-yn-no': {'oddID': 'doubleDouble-DENNIS_SCHRODER_BROOKLYN_NETS_NBA-game-yn-no',
#      'statID': 'doubleDouble',
#      'statEntityID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'no',
#      'playerID': 'DENNIS_SCHRODER_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '-3000',
#      'odds': '-870'},
#     'points-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'points-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '6.5',
#      'bookOdds': '-130',
#      'overUnder': '7.5',
#      'odds': '+125'},
#     'points-home-reg-ml3way-home': {'oddID': 'points-home-reg-ml3way-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'reg',
#      'betTypeID': 'ml3way',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+227',
#      'odds': '+250'},
#     'blocks-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'blocks-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'blocks',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'odds': '+175',
#      'bookOdds': '+153'},
#     'steals-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'steals-JONATHAN_ISAAC_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'steals',
#      'statEntityID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JONATHAN_ISAAC_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+155',
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'bookOdds': '+135'},
#     'blocks+steals-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-over': {'oddID': 'blocks+steals-CAMERON_JOHNSON_BROOKLYN_NETS_NBA-game-ou-over',
#      'statID': 'blocks+steals',
#      'statEntityID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'CAMERON_JOHNSON_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '1.5',
#      'bookOverUnder': '1.5',
#      'odds': '+140',
#      'bookOdds': '+125'},
#     'rebounds-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'rebounds-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'rebounds',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '1.5',
#      'overUnder': '2.5',
#      'bookOdds': '-184',
#      'odds': '+160'},
#     'rebounds+assists-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'rebounds+assists-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'rebounds+assists',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '8.5',
#      'overUnder': '8.5',
#      'bookOdds': '-125'},
#     'doubleDouble-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-yn-yes': {'oddID': 'doubleDouble-GOGA_BITADZE_ORLANDO_MAGIC_NBA-game-yn-yes',
#      'statID': 'doubleDouble',
#      'statEntityID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'yes',
#      'playerID': 'GOGA_BITADZE_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+525',
#      'odds': '+575'},
#     'blocks-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'blocks-ANTHONY_BLACK_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'blocks',
#      'statEntityID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'ANTHONY_BLACK_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'odds': '+180',
#      'bookOdds': '+160'},
#     'doubleDouble-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-yn-yes': {'oddID': 'doubleDouble-FRANZ_WAGNER_ORLANDO_MAGIC_NBA-game-yn-yes',
#      'statID': 'doubleDouble',
#      'statEntityID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'yes',
#      'playerID': 'FRANZ_WAGNER_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+375',
#      'odds': '+415'},
#     'steals-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-under': {'oddID': 'steals-BEN_SIMMONS_BROOKLYN_NETS_NBA-game-ou-under',
#      'statID': 'steals',
#      'statEntityID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'BEN_SIMMONS_BROOKLYN_NETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'bookOdds': '+110',
#      'odds': '+125'},
#     'turnovers-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over': {'oddID': 'turnovers-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-over',
#      'statID': 'turnovers',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-160',
#      'overUnder': '0.5',
#      'bookOverUnder': '0.5',
#      'bookOdds': '-200'},
#     'assists-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under': {'oddID': 'assists-WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA-game-ou-under',
#      'statID': 'assists',
#      'statEntityID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'WENDELL_CARTER_JR_ORLANDO_MAGIC_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
# ...
#      'statID': 'points',
#      'statEntityID': 'CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '13.5',
#      'overUnder': '14.5',
#      'bookOdds': '-125',
#      'odds': '+120'},
#     'threePointersMade-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-under': {'oddID': 'threePointersMade-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-under',
#      'statID': 'threePointersMade',
#      'statEntityID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '0.5',
#      'overUnder': '0.5',
#      'bookOdds': '+151',
#      'odds': '+170'},
#     'points-away-game-ou-under': {'oddID': 'points-away-game-ou-under',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '112.5',
#      'overUnder': '112.5',
#      'bookOdds': '-115'},
#     'points-all-3q-ou-under': {'oddID': 'points-all-3q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '3q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '55.5',
#      'overUnder': '55.5',
#      'bookOdds': '-118'},
#     'doubleDouble-JAMAL_MURRAY_DENVER_NUGGETS_NBA-game-yn-yes': {'oddID': 'doubleDouble-JAMAL_MURRAY_DENVER_NUGGETS_NBA-game-yn-yes',
#      'statID': 'doubleDouble',
#      'statEntityID': 'JAMAL_MURRAY_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'yn',
#      'sideID': 'yes',
#      'playerID': 'JAMAL_MURRAY_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOdds': '+715',
#      'odds': '+780'},
#     'points-CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA-game-ou-under': {'oddID': 'points-CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA-game-ou-under',
#      'statID': 'points',
#      'statEntityID': 'CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '13.5',
#      'overUnder': '14.5',
#      'bookOdds': '-106',
#      'odds': '-120'},
#     'points-all-2q-ou-over': {'oddID': 'points-all-2q-ou-over',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '2q',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '57',
#      'bookOdds': '-121',
#      'bookOverUnder': '56.5'},
#     'threePointersMade-MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA-game-ou-under': {'oddID': 'threePointersMade-MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA-game-ou-under',
#      'statID': 'threePointersMade',
#      'statEntityID': 'MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '2.5',
#      'odds': '+100',
#      'overUnder': '2.5',
#      'bookOdds': '-105'},
#     'steals-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-under': {'oddID': 'steals-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-under',
#      'statID': 'steals',
#      'statEntityID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '1.5',
#      'overUnder': '1',
#      'odds': '+100',
#      'bookOdds': '-220'},
#     'points+rebounds+assists-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-under': {'oddID': 'points+rebounds+assists-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-under',
#      'statID': 'points+rebounds+assists',
#      'statEntityID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '20.5',
#      'overUnder': '21.5',
#      'bookOdds': '-125',
#      'odds': '-140'},
#     'points-away-2q-ou-under': {'oddID': 'points-away-2q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '28.5',
#      'overUnder': '29',
#      'bookOdds': '-104',
#      'odds': '+100'},
#     'points-away-2h-ml-away': {'oddID': 'points-away-2h-ml-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2h',
#      'betTypeID': 'ml',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-115',
#      'bookOdds': '-134'},
#     'threePointersMade-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-over': {'oddID': 'threePointersMade-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-over',
#      'statID': 'threePointersMade',
#      'statEntityID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '0.5',
#      'overUnder': '0.5',
#      'bookOdds': '-202',
#      'odds': '-170'},
#     'points+assists-CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA-game-ou-over': {'oddID': 'points+assists-CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA-game-ou-over',
#      'statID': 'points+assists',
#      'statEntityID': 'CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'CHRISTIAN_BRAUN_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '16.5',
#      'overUnder': '16.5',
#      'bookOdds': '-110'},
#     'threePointersMade-MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA-game-ou-over': {'oddID': 'threePointersMade-MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA-game-ou-over',
#      'statID': 'threePointersMade',
#      'statEntityID': 'MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '2.5',
#      'odds': '+100',
#      'overUnder': '2.5',
#      'bookOdds': '-125'},
#     'points-home-game-ou-over': {'oddID': 'points-home-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '110.5',
#      'overUnder': '110',
#      'bookOdds': '-108'},
#     'blocks-IVICA_ZUBAC_LA_CLIPPERS_NBA-game-ou-under': {'oddID': 'blocks-IVICA_ZUBAC_LA_CLIPPERS_NBA-game-ou-under',
#      'statID': 'blocks',
#      'statEntityID': 'IVICA_ZUBAC_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'IVICA_ZUBAC_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '1.5',
#      'overUnder': '1.5',
#      'bookOdds': '-227',
#      'odds': '-180'},
#     'points-away-3q-ml-away': {'oddID': 'points-away-3q-ml-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '3q',
#      'betTypeID': 'ml',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '-110',
#      'bookOdds': '-126'},
#     'blocks-PEYTON_WATSON_DENVER_NUGGETS_NBA-game-ou-under': {'oddID': 'blocks-PEYTON_WATSON_DENVER_NUGGETS_NBA-game-ou-under',
#      'statID': 'blocks',
#      'statEntityID': 'PEYTON_WATSON_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'PEYTON_WATSON_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '1.5',
#      'overUnder': '1',
#      'odds': '+100',
#      'bookOdds': '-220'},
#     'points-home-2h-ml-home': {'oddID': 'points-home-2h-ml-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '2h',
#      'betTypeID': 'ml',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+115',
#      'bookOdds': '+105'},
#     'rebounds+assists-MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA-game-ou-under': {'oddID': 'rebounds+assists-MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA-game-ou-under',
#      'statID': 'rebounds+assists',
#      'statEntityID': 'MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'MICHAEL_PORTER_JR_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '8.5',
#      'overUnder': '9',
#      'bookOdds': '-110'},
#     'points-all-2h-ou-under': {'oddID': 'points-all-2h-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '2h',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '107.5',
#      'overUnder': '108',
#      'bookOdds': '-121'},
#     'points-all-4q-ou-over': {'oddID': 'points-all-4q-ou-over',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '4q',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '52.5',
#      'overUnder': '53',
#      'bookOdds': '-110'},
#     'points-away-2h-sp-away': {'oddID': 'points-away-2h-sp-away',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2h',
#      'betTypeID': 'sp',
#      'sideID': 'away',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookSpread': '-1.5',
#      'bookOdds': '-106',
#      'spread': '-0.5'},
#     'points-away-2q-ou-over': {'oddID': 'points-away-2q-ou-over',
#      'statID': 'points',
#      'statEntityID': 'away',
#      'periodID': '2q',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '28.5',
#      'overUnder': '29',
#      'bookOdds': '-117',
#      'odds': '+100'},
#     'points-home-game-ou-under': {'oddID': 'points-home-game-ou-under',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '110.5',
#      'overUnder': '110',
#      'bookOdds': '-120'},
#     'points-KAI_JONES_LA_CLIPPERS_NBA-game-ou-over': {'oddID': 'points-KAI_JONES_LA_CLIPPERS_NBA-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'KAI_JONES_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'KAI_JONES_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '10.5',
#      'bookOverUnder': '9.5',
#      'odds': '+115',
#      'bookOdds': '-136'},
#     'points-home-2h-sp-home': {'oddID': 'points-home-2h-sp-home',
#      'statID': 'points',
#      'statEntityID': 'home',
#      'periodID': '2h',
#      'betTypeID': 'sp',
#      'sideID': 'home',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookSpread': '+1.5',
#      'bookOdds': '-124',
#      'spread': '+0.5'},
#     'points-all-4q-ou-under': {'oddID': 'points-all-4q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '4q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '52.5',
#      'overUnder': '53',
#      'bookOdds': '-120'},
#     'points-all-game-ou-over': {'oddID': 'points-all-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOdds': '-110',
#      'bookOverUnder': '222.5',
#      'overUnder': '222.5'},
#     'threePointersMade-JAMAL_MURRAY_DENVER_NUGGETS_NBA-game-ou-under': {'oddID': 'threePointersMade-JAMAL_MURRAY_DENVER_NUGGETS_NBA-game-ou-under',
#      'statID': 'threePointersMade',
#      'statEntityID': 'JAMAL_MURRAY_DENVER_NUGGETS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JAMAL_MURRAY_DENVER_NUGGETS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'overUnder': '2.5',
#      'bookOverUnder': '2.5',
#      'odds': '-145',
#      'bookOdds': '-175'},
#     'points-all-game-ou-under': {'oddID': 'points-all-game-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '222.5',
#      'overUnder': '222.5',
#      'bookOdds': '-111'},
#     'points-all-2q-ou-under': {'oddID': 'points-all-2q-ou-under',
#      'statID': 'points',
#      'statEntityID': 'all',
#      'periodID': '2q',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'overUnder': '57',
#      'bookOdds': '-109',
#      'bookOverUnder': '56.5'},
#     'points-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-over': {'oddID': 'points-RUSSELL_WESTBROOK_LA_CLIPPERS_NBA-game-ou-over',
#      'statID': 'points',
#      'statEntityID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'over',
#      'playerID': 'RUSSELL_WESTBROOK_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'bookOverUnder': '10.5',
#      'overUnder': '11.5',
#      'odds': '+115',
#      'bookOdds': '-129'},
#     'points+rebounds-JAMES_HARDEN_LA_CLIPPERS_NBA-game-ou-under': {'oddID': 'points+rebounds-JAMES_HARDEN_LA_CLIPPERS_NBA-game-ou-under',
#      'statID': 'points+rebounds',
#      'statEntityID': 'JAMES_HARDEN_LA_CLIPPERS_NBA',
#      'periodID': 'game',
#      'betTypeID': 'ou',
#      'sideID': 'under',
#      'playerID': 'JAMES_HARDEN_LA_CLIPPERS_NBA',
#      'started': False,
#      'ended': False,
#      'cancelled': False,
#      'available': True,
#      'odds': '+100',
#      'bookOverUnder': '28.5',
#      'overUnder': '28.5',
#      'bookOdds': '-122'}}}]}

# %%
length = len(data['data'])

# %%
length
# Out:
# 10

# %%
data['data'][1]['teams']['away']
# Out:
# {'statEntityID': 'away',
#  'names': {'nickname': 'Pacers',
#   'short': 'IND',
#   'location': 'Indiana',
#   'medium': 'Pacers',
#   'long': 'Indiana Pacers'},
#  'teamID': 'INDIANA_PACERS_NBA',
#  'colors': {'secondary': '#FFC633',
#   'primaryContrast': '#FFFFFF',
#   'secondaryContrast': '#00275D',
#   'primary': '#00275D'}}

# %%
for value in data['data'][7]['players']:
    print(value)
# Out:
# CHRIS_PAUL_SAN_ANTONIO_SPURS_NBA
# DOMANTAS_SABONIS_SACRAMENTO_KINGS_NBA
# DEAARON_FOX_SACRAMENTO_KINGS_NBA
# STEPHON_CASTLE_SAN_ANTONIO_SPURS_NBA
# MALIK_MONK_SACRAMENTO_KINGS_NBA
# VICTOR_WEMBANYAMA_SAN_ANTONIO_SPURS_NBA
# DEVIN_VASSELL_SAN_ANTONIO_SPURS_NBA
# HARRISON_BARNES_SACRAMENTO_KINGS_NBA
# KEON_ELLIS_SACRAMENTO_KINGS_NBA
# KEEGAN_MURRAY_SACRAMENTO_KINGS_NBA
# JULIAN_CHAMPAGNIE_SAN_ANTONIO_SPURS_NBA
# KELDON_JOHNSON_SAN_ANTONIO_SPURS_NBA
# TRE_JONES_SAN_ANTONIO_SPURS_NBA
# COLBY_JONES_SACRAMENTO_KINGS_NBA

# %%
data['data'][7]['players']
# Out:
# {'CHRIS_PAUL_SAN_ANTONIO_SPURS_NBA': {'playerID': 'CHRIS_PAUL_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Chris',
#   'lastName': 'Paul',
#   'name': 'Chris Paul',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'DOMANTAS_SABONIS_SACRAMENTO_KINGS_NBA': {'playerID': 'DOMANTAS_SABONIS_SACRAMENTO_KINGS_NBA',
#   'firstName': 'Domantas',
#   'lastName': 'Sabonis',
#   'name': 'Domantas Sabonis',
#   'teamID': 'SACRAMENTO_KINGS_NBA'},
#  'DEAARON_FOX_SACRAMENTO_KINGS_NBA': {'playerID': 'DEAARON_FOX_SACRAMENTO_KINGS_NBA',
#   'firstName': "De'Aaron",
#   'lastName': 'Fox',
#   'name': "De'Aaron Fox",
#   'teamID': 'SACRAMENTO_KINGS_NBA'},
#  'STEPHON_CASTLE_SAN_ANTONIO_SPURS_NBA': {'playerID': 'STEPHON_CASTLE_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Stephon',
#   'lastName': 'Castle',
#   'name': 'Stephon Castle',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'MALIK_MONK_SACRAMENTO_KINGS_NBA': {'playerID': 'MALIK_MONK_SACRAMENTO_KINGS_NBA',
#   'firstName': 'Malik',
#   'lastName': 'Monk',
#   'name': 'Malik Monk',
#   'teamID': 'SACRAMENTO_KINGS_NBA'},
#  'VICTOR_WEMBANYAMA_SAN_ANTONIO_SPURS_NBA': {'playerID': 'VICTOR_WEMBANYAMA_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Victor',
#   'lastName': 'Wembanyama',
#   'name': 'Victor Wembanyama',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'DEVIN_VASSELL_SAN_ANTONIO_SPURS_NBA': {'playerID': 'DEVIN_VASSELL_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Devin',
#   'lastName': 'Vassell',
#   'name': 'Devin Vassell',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'HARRISON_BARNES_SACRAMENTO_KINGS_NBA': {'playerID': 'HARRISON_BARNES_SACRAMENTO_KINGS_NBA',
#   'firstName': 'Harrison',
#   'lastName': 'Barnes',
#   'name': 'Harrison Barnes',
#   'teamID': 'SACRAMENTO_KINGS_NBA'},
#  'KEON_ELLIS_SACRAMENTO_KINGS_NBA': {'playerID': 'KEON_ELLIS_SACRAMENTO_KINGS_NBA',
#   'firstName': 'Keon',
#   'lastName': 'Ellis',
#   'name': 'Keon Ellis',
#   'teamID': 'SACRAMENTO_KINGS_NBA'},
#  'KEEGAN_MURRAY_SACRAMENTO_KINGS_NBA': {'playerID': 'KEEGAN_MURRAY_SACRAMENTO_KINGS_NBA',
#   'firstName': 'Keegan',
#   'lastName': 'Murray',
#   'name': 'Keegan Murray',
#   'teamID': 'SACRAMENTO_KINGS_NBA'},
#  'JULIAN_CHAMPAGNIE_SAN_ANTONIO_SPURS_NBA': {'playerID': 'JULIAN_CHAMPAGNIE_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Julian',
#   'lastName': 'Champagnie',
#   'name': 'Julian Champagnie',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'KELDON_JOHNSON_SAN_ANTONIO_SPURS_NBA': {'playerID': 'KELDON_JOHNSON_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Keldon',
#   'lastName': 'Johnson',
#   'name': 'Keldon Johnson',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'TRE_JONES_SAN_ANTONIO_SPURS_NBA': {'playerID': 'TRE_JONES_SAN_ANTONIO_SPURS_NBA',
#   'firstName': 'Tre',
#   'lastName': 'Jones',
#   'name': 'Tre Jones',
#   'teamID': 'SAN_ANTONIO_SPURS_NBA'},
#  'COLBY_JONES_SACRAMENTO_KINGS_NBA': {'playerID': 'COLBY_JONES_SACRAMENTO_KINGS_NBA',
#   'firstName': 'Mason',
#   'lastName': 'Jones',
#   'name': 'Mason Jones',
#   'teamID': 'SACRAMENTO_KINGS_NBA'}}

# %%
def extract_player_point_props(json_data, i):
    player_props = {}
    pattern = r"points-([A-Z_]+)_NBA-game-ou-(over|under)"
    three_word_teams = ["new", "golden", "los", "oklahoma", "san", "portland"]
        
    for key, value in json_data['odds'].items():
        match = re.match(pattern, key)
        if match:
            full_name = match.group(1).replace('_', ' ').lower()
            over_under = match.group(2).lower()
            
            # Split the full name into parts
            name_parts = full_name.split()
            # Check if the third-to-last word is in the list of three-word team prefixes
            if len(name_parts) > 3 and name_parts[-3] in three_word_teams:
                player_name = ' '.join(name_parts[:-3])  # Everything except the last three words
                team_name = ' '.join(name_parts[-3:])    # Last three words
            else:
                player_name = ' '.join(name_parts[:-2])  # Everything except the last two words
                team_name = ' '.join(name_parts[-2:])    # Last two words
            
            if player_name not in player_props:
                player_props[player_name] = {
                    'team': team_name,
                    'line': value['overUnder'],
                    'over': {'odds': None, 'book_line': None},
                    'under': {'odds': None, 'book_line': None}
                }
            try:
                if value['sideID'].lower() == 'over':
                    player_props[player_name]['over'] = {
                        'book_line': value['bookOdds']
                    }
                elif value['sideID'].lower() == 'under':
                    player_props[player_name]['under'] = {
                        'book_line': value['bookOdds']
                    }
            except:
                print('player not playing')
            print(player_name)
    for value in json_data['players']:
        
        name = json_data['players'][value]['name'].lower().replace('-', '').replace('.', '').replace(' ii', '').replace("'", "")
        
        if name == "josh giddey":
            name = "joshua giddey"
        if name == 'scotty pippen jr':
            name = "scotty pippen"
        if name == 'andre jackson jr':
            name = "andre jackson"
        if name == 'jesse edwards':
            name = 'anthony edwards'
        if name == 'trey murphyi':
            name = 'trey murphy'
        if name == 'lindy watersi':
            name = 'lindy waters'
        if name == 'pj washington jr':
            name = 'pj washington'
        if player_name == 'jeenathan williams':
            continue
        if name == 'mason jones':
            name = 'colby jones'
        
        if name not in player_props:
            player_props[name] = {
                'team': team_name,
                'line': None,
                'over': {'odds': None, 'book_line': None},
                'under': {'odds': None, 'book_line': None}
            }
        print(json_data['players'][value]['teamID'], name)

        if json_data['players'][value]['teamID'] == data['data'][i]['teams']['home']['teamID']:
            player_props[name]['opp'] = data['data'][i]['teams']['away']['names']['short']
        else:
            player_props[name]['opp'] = data['data'][i]['teams']['home']['names']['short']


    return player_props

# %%
game_data = []
for i in range(length):
    d = extract_player_point_props(data['data'][i], i)
    game_data.append(d)
# Out:
# jonathan isaac
# cameron johnson
# anthony black
# anthony black
# franz wagner
# moritz wagner
# ben simmons
# goga bitadze
# ben simmons
# dennis schroder
# goga bitadze
# moritz wagner
# jonathan isaac
# jalen suggs
# cameron johnson
# wendell carter jr
# franz wagner
# jalen suggs
# wendell carter jr
# dennis schroder
# ORLANDO_MAGIC_NBA goga bitadze
# BROOKLYN_NETS_NBA cameron johnson
# BROOKLYN_NETS_NBA ben simmons
# ORLANDO_MAGIC_NBA jalen suggs
# ORLANDO_MAGIC_NBA franz wagner
# BROOKLYN_NETS_NBA dennis schroder
# ORLANDO_MAGIC_NBA wendell carter jr
# ORLANDO_MAGIC_NBA jonathan isaac
# ORLANDO_MAGIC_NBA anthony black
# ORLANDO_MAGIC_NBA moritz wagner
# jaren jackson jr
# jaren jackson jr
# myles turner
# bennedict mathurin
# jake laravia
# bennedict mathurin
# ja morant
# jake laravia
# gg jackson
# brandon clarke
# scotty pippen
# desmond bane
# desmond bane
# scotty pippen
# marcus smart
# marcus smart
# obi toppin
# santi aldama
# tyrese haliburton
# myles turner
# brandon clarke
# pascal siakam
# tyrese haliburton
# pascal siakam
# luke kennard
# tj mcconnell
# ja morant
# obi toppin
# gg jackson
# luke kennard
# tj mcconnell
# santi aldama
# MEMPHIS_GRIZZLIES_NBA gg jackson
# INDIANA_PACERS_NBA tyrese haliburton
# INDIANA_PACERS_NBA myles turner
# INDIANA_PACERS_NBA pascal siakam
# MEMPHIS_GRIZZLIES_NBA ja morant
# INDIANA_PACERS_NBA obi toppin
# INDIANA_PACERS_NBA bennedict mathurin
# INDIANA_PACERS_NBA tj mcconnell
# MEMPHIS_GRIZZLIES_NBA santi aldama
# MEMPHIS_GRIZZLIES_NBA desmond bane
# MEMPHIS_GRIZZLIES_NBA brandon clarke
# MEMPHIS_GRIZZLIES_NBA jaren jackson jr
# INDIANA_PACERS_NBA isaiah jackson
# INDIANA_PACERS_NBA andrew nembhard
# MEMPHIS_GRIZZLIES_NBA marcus smart
# MEMPHIS_GRIZZLIES_NBA luke kennard
# MEMPHIS_GRIZZLIES_NBA scotty pippen
# MEMPHIS_GRIZZLIES_NBA jake laravia
# caris levert
# jaylen brown
# jaylen brown
# caris levert
# donovan mitchell
# kristaps porzingis
# georges niang
# sam merrill
# sam merrill
# ty jerome
# darius garland
# darius garland
# isaac okoro
# evan mobley
# evan mobley
# isaac okoro
# georges niang
# derrick white
# jarrett allen
# donovan mitchell
# jarrett allen
# jrue holiday
# ty jerome
# jayson tatum
# kristaps porzingis
# derrick white
# jayson tatum
# jrue holiday
# BOSTON_CELTICS_NBA jaylen brown
# CLEVELAND_CAVALIERS_NBA jarrett allen
# BOSTON_CELTICS_NBA derrick white
# CLEVELAND_CAVALIERS_NBA isaac okoro
# CLEVELAND_CAVALIERS_NBA evan mobley
# CLEVELAND_CAVALIERS_NBA darius garland
# BOSTON_CELTICS_NBA jayson tatum
# BOSTON_CELTICS_NBA kristaps porzingis
# CLEVELAND_CAVALIERS_NBA donovan mitchell
# BOSTON_CELTICS_NBA jrue holiday
# CLEVELAND_CAVALIERS_NBA georges niang
# CLEVELAND_CAVALIERS_NBA caris levert
# CLEVELAND_CAVALIERS_NBA sam merrill
# CLEVELAND_CAVALIERS_NBA ty jerome
# haywood highsmith
# chris boucher
# chris boucher
# terry rozier
# ochai agbaji
# rj barrett
# rj barrett
# davion mitchell
# ochai agbaji
# tyler herro
# haywood highsmith
# bam adebayo
# scottie barnes
# bam adebayo
# jimmy butler
# jaime jaquez jr
# terry rozier
# duncan robinson
# duncan robinson
# jimmy butler
# jakob poeltl
# scottie barnes
# jaime jaquez jr
# jakob poeltl
# tyler herro
# davion mitchell
# TORONTO_RAPTORS_NBA jakob poeltl
# MIAMI_HEAT_NBA bam adebayo
# MIAMI_HEAT_NBA haywood highsmith
# MIAMI_HEAT_NBA tyler herro
# TORONTO_RAPTORS_NBA rj barrett
# MIAMI_HEAT_NBA jimmy butler
# TORONTO_RAPTORS_NBA scottie barnes
# MIAMI_HEAT_NBA duncan robinson
# TORONTO_RAPTORS_NBA ochai agbaji
# TORONTO_RAPTORS_NBA jakobe walter
# MIAMI_HEAT_NBA terry rozier
# MIAMI_HEAT_NBA jaime jaquez jr
# TORONTO_RAPTORS_NBA chris boucher
# TORONTO_RAPTORS_NBA davion mitchell
# jeremiah robinsonearl
# jeremiah robinsonearl
# miles mcbride
# josh hart
# trey murphy
# jalen brunson
# dejounte murray
# dejounte murray
# jalen brunson
# miles mcbride
# trey murphy
# og anunoby
# og anunoby
# cj mccollum
# yves missi
# josh hart
# yves missi
# cj mccollum
# mikal bridges
# mikal bridges
# NEW_ORLEANS_PELICANS_NBA dejounte murray
# NEW_YORK_KNICKS_NBA og anunoby
# NEW_ORLEANS_PELICANS_NBA cj mccollum
# NEW_YORK_KNICKS_NBA mikal bridges
# NEW_YORK_KNICKS_NBA josh hart
# NEW_YORK_KNICKS_NBA jalen brunson
# NEW_ORLEANS_PELICANS_NBA trey murphy
# NEW_ORLEANS_PELICANS_NBA yves missi
# NEW_ORLEANS_PELICANS_NBA jeremiah robinsonearl
# NEW_YORK_KNICKS_NBA miles mcbride
# shai gilgeousalexander
# jalen williams
# jalen williams
# dillon brooks
# isaiah hartenstein
# tari eason
# amen thompson
# isaiah hartenstein
# dillon brooks
# jeenathan williams
# jabari smith
# luguentz dort
# shai gilgeousalexander
# alperen sengun
# tari eason
# alperen sengun
# jeenathan williams
# fred vanvleet
# amen thompson
# jalen green
# jalen green
# fred vanvleet
# jabari smith
# luguentz dort
# HOUSTON_ROCKETS_NBA dillon brooks
# HOUSTON_ROCKETS_NBA jalen green
# HOUSTON_ROCKETS_NBA fred vanvleet
# OKLAHOMA_CITY_THUNDER_NBA shai gilgeousalexander
# OKLAHOMA_CITY_THUNDER_NBA isaiah hartenstein
# HOUSTON_ROCKETS_NBA jabari smith
# HOUSTON_ROCKETS_NBA nate williams
# HOUSTON_ROCKETS_NBA tari eason
# HOUSTON_ROCKETS_NBA amen thompson
# OKLAHOMA_CITY_THUNDER_NBA luguentz dort
# OKLAHOMA_CITY_THUNDER_NBA cason wallace
# HOUSTON_ROCKETS_NBA alperen sengun
# OKLAHOMA_CITY_THUNDER_NBA jalen williams
# austin reaves
# austin reaves
# keyonte george
# keyonte george
# walker kessler
# lauri markkanen
# collin sexton
# john collins
# lebron james
# lauri markkanen
# lebron james
# walker kessler
# collin sexton
# anthony davis
# anthony davis
# john collins
# LOS_ANGELES_LAKERS_NBA anthony davis
# UTAH_JAZZ_NBA lauri markkanen
# LOS_ANGELES_LAKERS_NBA lebron james
# UTAH_JAZZ_NBA collin sexton
# UTAH_JAZZ_NBA walker kessler
# UTAH_JAZZ_NBA john collins
# LOS_ANGELES_LAKERS_NBA austin reaves
# LOS_ANGELES_LAKERS_NBA dalton knecht
# UTAH_JAZZ_NBA keyonte george
# LOS_ANGELES_LAKERS_NBA rui hachimura
# keldon johnson
# keldon johnson
# tre jones
# harrison barnes
# harrison barnes
# tre jones
# deaaron fox
# julian champagnie
# malik monk
# keon ellis
# domantas sabonis
# victor wembanyama
# colby jones
# colby jones
# devin vassell
# keegan murray
# devin vassell
# keegan murray
# chris paul
# julian champagnie
# domantas sabonis
# chris paul
# victor wembanyama
# stephon castle
# keon ellis
# deaaron fox
# stephon castle
# malik monk
# SAN_ANTONIO_SPURS_NBA chris paul
# SACRAMENTO_KINGS_NBA domantas sabonis
# SACRAMENTO_KINGS_NBA deaaron fox
# SAN_ANTONIO_SPURS_NBA stephon castle
# SACRAMENTO_KINGS_NBA malik monk
# SAN_ANTONIO_SPURS_NBA victor wembanyama
# SAN_ANTONIO_SPURS_NBA devin vassell
# SACRAMENTO_KINGS_NBA harrison barnes
# SACRAMENTO_KINGS_NBA keon ellis
# SACRAMENTO_KINGS_NBA keegan murray
# SAN_ANTONIO_SPURS_NBA julian champagnie
# SAN_ANTONIO_SPURS_NBA keldon johnson
# SAN_ANTONIO_SPURS_NBA tre jones
# SACRAMENTO_KINGS_NBA colby jones
# luka doncic
# anfernee simons
# anfernee simons
# toumani camara
# luka doncic
# toumani camara
# shaedon sharpe
# deandre ayton
# deandre ayton
# shaedon sharpe
# jerami grant
# jerami grant
# PORTLAND_TRAIL_BLAZERS_NBA deandre ayton
# DALLAS_MAVERICKS_NBA luka doncic
# DALLAS_MAVERICKS_NBA kyrie irving
# PORTLAND_TRAIL_BLAZERS_NBA anfernee simons
# PORTLAND_TRAIL_BLAZERS_NBA shaedon sharpe
# DALLAS_MAVERICKS_NBA dereck lively
# PORTLAND_TRAIL_BLAZERS_NBA deni avdija
# DALLAS_MAVERICKS_NBA pj washington
# PORTLAND_TRAIL_BLAZERS_NBA toumani camara
# DALLAS_MAVERICKS_NBA naji marshall
# PORTLAND_TRAIL_BLAZERS_NBA jerami grant
# DALLAS_MAVERICKS_NBA klay thompson
# PORTLAND_TRAIL_BLAZERS_NBA scoot henderson
# jamal murray
# kai jones
# julian strawther
# jamal murray
# julian strawther
# michael porter jr
# ivica zubac
# james harden
# peyton watson
# ivica zubac
# james harden
# peyton watson
# michael porter jr
# nikola jokic
# nikola jokic
# russell westbrook
# christian braun
# christian braun
# kai jones
# russell westbrook
# DENVER_NUGGETS_NBA michael porter jr
# LA_CLIPPERS_NBA kai jones
# LA_CLIPPERS_NBA james harden
# DENVER_NUGGETS_NBA nikola jokic
# DENVER_NUGGETS_NBA jamal murray
# LA_CLIPPERS_NBA russell westbrook
# DENVER_NUGGETS_NBA christian braun
# LA_CLIPPERS_NBA ivica zubac
# DENVER_NUGGETS_NBA peyton watson
# DENVER_NUGGETS_NBA julian strawther
# LA_CLIPPERS_NBA norman powell
# LA_CLIPPERS_NBA amir coffey

# %% [markdown]
# ### Below is commented out since only needed once

# %%
game_data
# Out:
# [{'jonathan isaac': {'team': 'orlando magic',
#    'line': '6.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-118'},
#    'opp': 'BKN'},
#   'cameron johnson': {'team': 'brooklyn nets',
#    'line': '17.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'},
#    'opp': 'ORL'},
#   'anthony black': {'team': 'orlando magic',
#    'line': '7.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '+100'},
#    'opp': 'BKN'},
#   'franz wagner': {'team': 'orlando magic',
#    'line': '26.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'BKN'},
#   'moritz wagner': {'team': 'orlando magic',
#    'line': '11.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-111'},
#    'opp': 'BKN'},
#   'ben simmons': {'team': 'brooklyn nets',
#    'line': '6',
#    'over': {'book_line': '-141'},
#    'under': {'book_line': '+105'},
#    'opp': 'ORL'},
#   'goga bitadze': {'team': 'orlando magic',
#    'line': '8.5',
#    'over': {'book_line': '-102'},
#    'under': {'book_line': '-130'},
#    'opp': 'BKN'},
#   'dennis schroder': {'team': 'brooklyn nets',
#    'line': '18.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-109'},
#    'opp': 'ORL'},
#   'jalen suggs': {'team': 'orlando magic',
#    'line': '16.5',
#    'over': {'book_line': '-104'},
#    'under': {'book_line': '-128'},
#    'opp': 'BKN'},
#   'wendell carter jr': {'team': 'orlando magic',
#    'line': '9.5',
#    'over': {'book_line': '-133'},
#    'under': {'book_line': '+100'},
#    'opp': 'BKN'}},
#  {'jaren jackson jr': {'team': 'memphis grizzlies',
#    'line': '20.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'IND'},
#   'myles turner': {'team': 'indiana pacers',
#    'line': '15.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'},
#    'opp': 'MEM'},
#   'bennedict mathurin': {'team': 'indiana pacers',
#    'line': '19.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-110'},
#    'opp': 'MEM'},
#   'jake laravia': {'team': 'memphis grizzlies',
#    'line': '5.5',
#    'over': {'book_line': '-116'},
#    'under': {'book_line': '-115'},
#    'opp': 'IND'},
#   'ja morant': {'team': 'memphis grizzlies',
#    'line': '22.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'IND'},
#   'gg jackson': {'team': 'memphis grizzlies',
#    'line': '20.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'},
#    'opp': 'IND'},
#   'brandon clarke': {'team': 'memphis grizzlies',
#    'line': '8.5',
#    'over': {'book_line': '-145'},
#    'under': {'book_line': '+109'},
#    'opp': 'IND'},
#   'scotty pippen': {'team': 'memphis grizzlies',
#    'line': '6.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-106'},
#    'opp': 'IND'},
#   'desmond bane': {'team': 'memphis grizzlies',
#    'line': '15.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'IND'},
#   'marcus smart': {'team': 'memphis grizzlies',
#    'line': '9.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-102'},
#    'opp': 'IND'},
#   'obi toppin': {'team': 'indiana pacers',
#    'line': '7.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-118'},
#    'opp': 'MEM'},
#   'santi aldama': {'team': 'memphis grizzlies',
#    'line': '9.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-122'},
#    'opp': 'IND'},
#   'tyrese haliburton': {'team': 'indiana pacers',
#    'line': '18.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-117'},
#    'opp': 'MEM'},
#   'pascal siakam': {'team': 'indiana pacers',
#    'line': '22.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-110'},
#    'opp': 'MEM'},
#   'luke kennard': {'team': 'memphis grizzlies',
#    'line': '6.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-118'},
#    'opp': 'IND'},
#   'tj mcconnell': {'team': 'indiana pacers',
#    'line': '11.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-108'},
#    'opp': 'MEM'},
#   'isaiah jackson': {'team': 'memphis grizzlies',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'MEM'},
#   'andrew nembhard': {'team': 'memphis grizzlies',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'MEM'}},
#  {'caris levert': {'team': 'cleveland cavaliers',
#    'line': '9.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'BOS'},
#   'jaylen brown': {'team': 'boston celtics',
#    'line': '24.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'CLE'},
#   'donovan mitchell': {'team': 'cleveland cavaliers',
#    'line': '26.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-119'},
#    'opp': 'BOS'},
#   'kristaps porzingis': {'team': 'boston celtics',
#    'line': '16.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-116'},
#    'opp': 'CLE'},
#   'georges niang': {'team': 'cleveland cavaliers',
#    'line': '8.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-108'},
#    'opp': 'BOS'},
#   'sam merrill': {'team': 'cleveland cavaliers',
#    'line': '6',
#    'over': {'book_line': '-138'},
#    'under': {'book_line': '+100'},
#    'opp': 'BOS'},
#   'ty jerome': {'team': 'cleveland cavaliers',
#    'line': '8.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-125'},
#    'opp': 'BOS'},
#   'darius garland': {'team': 'cleveland cavaliers',
#    'line': '19.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-117'},
#    'opp': 'BOS'},
#   'isaac okoro': {'team': 'cleveland cavaliers',
#    'line': '6.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-123'},
#    'opp': 'BOS'},
#   'evan mobley': {'team': 'cleveland cavaliers',
#    'line': '16.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-125'},
#    'opp': 'BOS'},
#   'derrick white': {'team': 'boston celtics',
#    'line': '16.5',
#    'over': {'book_line': '-124'},
#    'under': {'book_line': '-109'},
#    'opp': 'CLE'},
#   'jarrett allen': {'team': 'cleveland cavaliers',
#    'line': '12.5',
#    'over': {'book_line': '-136'},
#    'under': {'book_line': '+100'},
#    'opp': 'BOS'},
#   'jrue holiday': {'team': 'boston celtics',
#    'line': '11.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-103'},
#    'opp': 'CLE'},
#   'jayson tatum': {'team': 'boston celtics',
#    'line': '27.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-118'},
#    'opp': 'CLE'}},
#  {'haywood highsmith': {'team': 'miami heat',
#    'line': '5.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-120'},
#    'opp': 'TOR'},
#   'chris boucher': {'team': 'toronto raptors',
#    'line': '7.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'MIA'},
#   'terry rozier': {'team': 'miami heat',
#    'line': '10.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'TOR'},
#   'ochai agbaji': {'team': 'toronto raptors',
#    'line': '9.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'},
#    'opp': 'MIA'},
#   'rj barrett': {'team': 'toronto raptors',
#    'line': '23.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'},
#    'opp': 'MIA'},
#   'davion mitchell': {'team': 'toronto raptors',
#    'line': '5.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-114'},
#    'opp': 'MIA'},
#   'tyler herro': {'team': 'miami heat',
#    'line': '22.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-117'},
#    'opp': 'TOR'},
#   'bam adebayo': {'team': 'miami heat',
#    'line': '17.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'},
#    'opp': 'TOR'},
#   'scottie barnes': {'team': 'toronto raptors',
#    'line': '22.5',
#    'over': {'book_line': '-124'},
#    'under': {'book_line': '-110'},
#    'opp': 'MIA'},
#   'jimmy butler': {'team': 'miami heat',
#    'line': '19.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-113'},
#    'opp': 'TOR'},
#   'jaime jaquez jr': {'team': 'miami heat',
#    'line': '9.5',
#    'over': {'book_line': '-107'},
#    'under': {'book_line': '-123'},
#    'opp': 'TOR'},
#   'duncan robinson': {'team': 'miami heat',
#    'line': '11.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-117'},
#    'opp': 'TOR'},
#   'jakob poeltl': {'team': 'toronto raptors',
#    'line': '14.5',
#    'over': {'book_line': '-128'},
#    'under': {'book_line': '-103'},
#    'opp': 'MIA'},
#   'jakobe walter': {'team': 'toronto raptors',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'MIA'}},
#  {'jeremiah robinsonearl': {'team': 'new orleans pelicans',
#    'line': '6.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'NYK'},
#   'miles mcbride': {'team': 'new york knicks',
#    'line': '9.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '-104'},
#    'opp': 'NOP'},
#   'josh hart': {'team': 'new york knicks',
#    'line': '13.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-107'},
#    'opp': 'NOP'},
#   'trey murphy': {'team': 'new orleans pelicans',
#    'line': '19.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-115'},
#    'opp': 'NYK'},
#   'jalen brunson': {'team': 'new york knicks',
#    'line': '26.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-119'},
#    'opp': 'NOP'},
#   'dejounte murray': {'team': 'new orleans pelicans',
#    'line': '19.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'NYK'},
#   'og anunoby': {'team': 'new york knicks',
#    'line': '17.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-109'},
#    'opp': 'NOP'},
#   'cj mccollum': {'team': 'new orleans pelicans',
#    'line': '20.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-109'},
#    'opp': 'NYK'},
#   'yves missi': {'team': 'new orleans pelicans',
#    'line': '9.5',
#    'over': {'book_line': '-121'},
#    'under': {'book_line': '-108'},
#    'opp': 'NYK'},
#   'mikal bridges': {'team': 'new york knicks',
#    'line': '15.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-113'},
#    'opp': 'NOP'}},
#  {'shai gilgeousalexander': {'team': 'oklahoma city thunder',
#    'line': '30.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'},
#    'opp': 'HOU'},
#   'jalen williams': {'team': 'oklahoma city thunder',
#    'line': '21.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-120'},
#    'opp': 'HOU'},
#   'dillon brooks': {'team': 'houston rockets',
#    'line': '12.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-118'},
#    'opp': 'OKC'},
#   'isaiah hartenstein': {'team': 'oklahoma city thunder',
#    'line': '11.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'HOU'},
#   'tari eason': {'team': 'houston rockets',
#    'line': '11.5',
#    'over': {'book_line': '-123'},
#    'under': {'book_line': '-106'},
#    'opp': 'OKC'},
#   'amen thompson': {'team': 'houston rockets',
#    'line': '12.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-109'},
#    'opp': 'OKC'},
#   'jeenathan williams': {'team': 'houston rockets',
#    'line': '21.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-120'}},
#   'jabari smith': {'team': 'houston rockets',
#    'line': '11.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-105'},
#    'opp': 'OKC'},
#   'luguentz dort': {'team': 'oklahoma city thunder',
#    'line': '10',
#    'over': {'book_line': '-131'},
#    'under': {'book_line': '+100'},
#    'opp': 'HOU'},
#   'alperen sengun': {'team': 'houston rockets',
#    'line': '19.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-120'},
#    'opp': 'OKC'},
#   'fred vanvleet': {'team': 'houston rockets',
#    'line': '16.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-115'},
#    'opp': 'OKC'},
#   'jalen green': {'team': 'houston rockets',
#    'line': '17.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'OKC'},
#   'nate williams': {'team': 'oklahoma city thunder',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'OKC'},
#   'cason wallace': {'team': 'oklahoma city thunder',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'HOU'}},
#  {'austin reaves': {'team': 'los angeles lakers',
#    'line': '17.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'UTA'},
#   'keyonte george': {'team': 'utah jazz',
#    'line': '14.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-105'},
#    'opp': 'LAL'},
#   'walker kessler': {'team': 'utah jazz',
#    'line': '8.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-119'},
#    'opp': 'LAL'},
#   'lauri markkanen': {'team': 'utah jazz',
#    'line': '21.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-120'},
#    'opp': 'LAL'},
#   'collin sexton': {'team': 'utah jazz',
#    'line': '18.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-122'},
#    'opp': 'LAL'},
#   'john collins': {'team': 'utah jazz',
#    'line': '16.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'},
#    'opp': 'LAL'},
#   'lebron james': {'team': 'los angeles lakers',
#    'line': '24.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-112'},
#    'opp': 'UTA'},
#   'anthony davis': {'team': 'los angeles lakers',
#    'line': '28',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-110'},
#    'opp': 'UTA'},
#   'dalton knecht': {'team': 'utah jazz',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'UTA'},
#   'rui hachimura': {'team': 'utah jazz',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'UTA'}},
#  {'keldon johnson': {'team': 'san antonio spurs',
#    'line': '10.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'SAC'},
#   'tre jones': {'team': 'san antonio spurs',
#    'line': '4.5',
#    'over': {'book_line': '-127'},
#    'under': {'book_line': '-110'},
#    'opp': 'SAC'},
#   'harrison barnes': {'team': 'sacramento kings',
#    'line': '11.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-129'},
#    'opp': 'SAS'},
#   'deaaron fox': {'team': 'sacramento kings',
#    'line': '26.5',
#    'over': {'book_line': '-127'},
#    'under': {'book_line': '-105'},
#    'opp': 'SAS'},
#   'julian champagnie': {'team': 'san antonio spurs',
#    'line': '12.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-121'},
#    'opp': 'SAC'},
#   'malik monk': {'team': 'sacramento kings',
#    'line': '14.5',
#    'over': {'book_line': '+100'},
#    'under': {'book_line': '-132'},
#    'opp': 'SAS'},
#   'keon ellis': {'team': 'sacramento kings',
#    'line': '7.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-127'},
#    'opp': 'SAS'},
#   'domantas sabonis': {'team': 'sacramento kings',
#    'line': '18.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '-104'},
#    'opp': 'SAS'},
#   'victor wembanyama': {'team': 'san antonio spurs',
#    'line': '23.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-115'},
#    'opp': 'SAC'},
#   'colby jones': {'team': 'sacramento kings',
#    'line': '4.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-107'},
#    'opp': 'SAS'},
#   'devin vassell': {'team': 'san antonio spurs',
#    'line': '14.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-115'},
#    'opp': 'SAC'},
#   'keegan murray': {'team': 'sacramento kings',
#    'line': '12.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'SAS'},
#   'chris paul': {'team': 'san antonio spurs',
#    'line': '8.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-117'},
#    'opp': 'SAC'},
#   'stephon castle': {'team': 'san antonio spurs',
#    'line': '13.5',
#    'over': {'book_line': '-107'},
#    'under': {'book_line': '-125'},
#    'opp': 'SAC'}},
#  {'luka doncic': {'team': 'dallas mavericks',
#    'line': '27.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-120'},
#    'opp': 'POR'},
#   'anfernee simons': {'team': 'portland trail blazers',
#    'line': '19.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-120'},
#    'opp': 'DAL'},
#   'toumani camara': {'team': 'portland trail blazers',
#    'line': '9.5',
#    'over': {'book_line': '-102'},
#    'under': {'book_line': '-128'},
#    'opp': 'DAL'},
#   'shaedon sharpe': {'team': 'portland trail blazers',
#    'line': '17.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-111'},
#    'opp': 'DAL'},
#   'deandre ayton': {'team': 'portland trail blazers',
#    'line': '16.5',
#    'over': {'book_line': '-103'},
#    'under': {'book_line': '-130'},
#    'opp': 'DAL'},
#   'jerami grant': {'team': 'portland trail blazers',
#    'line': '14.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'DAL'},
#   'kyrie irving': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'dereck lively': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'deni avdija': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DAL'},
#   'pj washington': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'naji marshall': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'klay thompson': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'scoot henderson': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DAL'}},
#  {'jamal murray': {'team': 'denver nuggets',
#    'line': '18.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'LAC'},
#   'kai jones': {'team': 'la clippers',
#    'line': '10.5',
#    'over': {'book_line': '-136'},
#    'under': {'book_line': '+100'},
#    'opp': 'DEN'},
#   'julian strawther': {'team': 'denver nuggets',
#    'line': '7',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'LAC'},
#   'michael porter jr': {'team': 'denver nuggets',
#    'line': '18.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-120'},
#    'opp': 'LAC'},
#   'ivica zubac': {'team': 'la clippers',
#    'line': '16.5',
#    'over': {'book_line': '-102'},
#    'under': {'book_line': '-129'},
#    'opp': 'DEN'},
#   'james harden': {'team': 'la clippers',
#    'line': '22.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-118'},
#    'opp': 'DEN'},
#   'peyton watson': {'team': 'denver nuggets',
#    'line': '9.5',
#    'over': {'book_line': '-103'},
#    'under': {'book_line': '-129'},
#    'opp': 'LAC'},
#   'nikola jokic': {'team': 'denver nuggets',
#    'line': '28.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-112'},
#    'opp': 'LAC'},
#   'russell westbrook': {'team': 'la clippers',
#    'line': '11.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-103'},
#    'opp': 'DEN'},
#   'christian braun': {'team': 'denver nuggets',
#    'line': '14.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-106'},
#    'opp': 'LAC'},
#   'norman powell': {'team': 'la clippers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DEN'},
#   'amir coffey': {'team': 'la clippers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DEN'}}]

# %% [markdown]
# df = pd.DataFrame()
# df = df.reindex(range(1000))
# num_rows = len(df)
#
# ##### Calculate the start date
# start_date = datetime.now().date() - timedelta(days = 400)
#
# ##### Create a date range
# date_range = pd.date_range(start=start_date, periods=num_rows)
#
# ##### Add the 'Date' column to your DataFrame
# df['Date'] = date_range
#
# ##### Format the date as MM/DD if you prefer
# df['Date'] = df['Date'].dt.strftime('%Y/%m/%d')

# %%
df = pd.read_csv('prop_table.csv', index_col=0)
# Out:
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\3114025419.py:1: DtypeWarning: Columns (502,504,506,508,511,514,516,519,521,524,526,529,532,535,538,540,543,546,548,551,553,556,559,562,565,567,570,572,574,576,578,581,583,585,587,590,593,595,598,601,603,605,608,610,613,615,618,620,622,624,627,629,632,635,638,641,644,646,648,651,653,655,658,660,663,665,667,669,671,674,677,679,682,685,688,690,692,695,698,700,702,705,707,710,712,714,717,720,723,725,728,730,732,735,737,739,742,744,746,748,751,753,756,758,761,763,765,767,770,773,776,779,782,784,786,789,792,794,796,798,801,804,807,809,812,814,817,819,822,824,827,830,832,835,837,839,841,844,847,849,851,853,856,859,862,864,867,870,872,874,877,880,882,885,888,890,893,895,898,900,903,906,908,911,913,915,917,920,923,926,928,931,933,936,938,940,942,945,948,951,954,957,959,961,963,965,968,970,973,975,978,981,983,986,988,990,993,995,997,1000,1002,1005,1007,1010,1012,1014,1016,1018,1020,1022,1025,1028,1031,1033,1035,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1074,1075,1076,1077,1081,1082,1083,1087,1091,1092,1093,1094,1095,1096,1097,1100,1104,1108,1109,1110,1114,1115,1116,1117,1118,1119,1120,1121,1122,1123,1124,1125,1129,1132,1133,1134,1137,1140,1141,1145,1146,1147,1148,1149,1150,1151,1152,1153,1154,1158,1159,1163,1164,1165,1166,1167,1168,1169,1170,1171,1172,1173,1174,1175,1179,1180,1181,1182,1183,1184,1185,1186,1187,1191,1192,1193,1194,1198,1199,1200,1201,1202,1203,1206,1207,1208,1209,1210,1213,1214,1215,1216,1217,1218,1219,1220,1221,1222,1223,1224,1225,1226,1229,1230,1231,1232,1233,1234,1237,1238,1242,1243,1244,1248,1249,1250,1251,1255,1259,1260,1261,1262,1263,1264,1268,1269,1270,1271,1272,1273,1276,1279,1282,1283,1284,1285,1289,1290,1291,1292,1295,1299,1303,1304,1308,1311,1315,1316,1317,1318,1319,1323,1324,1328,1331,1335,1336,1337,1338,1339,1340,1341,1345,1348,1351,1352,1353,1357,1361,1365,1368,1372,1373,1377,1380,1381,1384,1385,1389,1393,1396,1399,1402,1405,1408,1411,1415,1419,1423,1424,1425,1429,1433,1437,1438,1442,1443,1444,1448,1451,1455,1459) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('prop_table.csv', index_col=0)

# %%
game_data
# Out:
# [{'jonathan isaac': {'team': 'orlando magic',
#    'line': '6.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-118'},
#    'opp': 'BKN'},
#   'cameron johnson': {'team': 'brooklyn nets',
#    'line': '17.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'},
#    'opp': 'ORL'},
#   'anthony black': {'team': 'orlando magic',
#    'line': '7.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '+100'},
#    'opp': 'BKN'},
#   'franz wagner': {'team': 'orlando magic',
#    'line': '26.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'BKN'},
#   'moritz wagner': {'team': 'orlando magic',
#    'line': '11.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-111'},
#    'opp': 'BKN'},
#   'ben simmons': {'team': 'brooklyn nets',
#    'line': '6',
#    'over': {'book_line': '-141'},
#    'under': {'book_line': '+105'},
#    'opp': 'ORL'},
#   'goga bitadze': {'team': 'orlando magic',
#    'line': '8.5',
#    'over': {'book_line': '-102'},
#    'under': {'book_line': '-130'},
#    'opp': 'BKN'},
#   'dennis schroder': {'team': 'brooklyn nets',
#    'line': '18.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-109'},
#    'opp': 'ORL'},
#   'jalen suggs': {'team': 'orlando magic',
#    'line': '16.5',
#    'over': {'book_line': '-104'},
#    'under': {'book_line': '-128'},
#    'opp': 'BKN'},
#   'wendell carter jr': {'team': 'orlando magic',
#    'line': '9.5',
#    'over': {'book_line': '-133'},
#    'under': {'book_line': '+100'},
#    'opp': 'BKN'}},
#  {'jaren jackson jr': {'team': 'memphis grizzlies',
#    'line': '20.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'IND'},
#   'myles turner': {'team': 'indiana pacers',
#    'line': '15.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'},
#    'opp': 'MEM'},
#   'bennedict mathurin': {'team': 'indiana pacers',
#    'line': '19.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-110'},
#    'opp': 'MEM'},
#   'jake laravia': {'team': 'memphis grizzlies',
#    'line': '5.5',
#    'over': {'book_line': '-116'},
#    'under': {'book_line': '-115'},
#    'opp': 'IND'},
#   'ja morant': {'team': 'memphis grizzlies',
#    'line': '22.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'IND'},
#   'gg jackson': {'team': 'memphis grizzlies',
#    'line': '20.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'},
#    'opp': 'IND'},
#   'brandon clarke': {'team': 'memphis grizzlies',
#    'line': '8.5',
#    'over': {'book_line': '-145'},
#    'under': {'book_line': '+109'},
#    'opp': 'IND'},
#   'scotty pippen': {'team': 'memphis grizzlies',
#    'line': '6.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-106'},
#    'opp': 'IND'},
#   'desmond bane': {'team': 'memphis grizzlies',
#    'line': '15.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'IND'},
#   'marcus smart': {'team': 'memphis grizzlies',
#    'line': '9.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-102'},
#    'opp': 'IND'},
#   'obi toppin': {'team': 'indiana pacers',
#    'line': '7.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-118'},
#    'opp': 'MEM'},
#   'santi aldama': {'team': 'memphis grizzlies',
#    'line': '9.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-122'},
#    'opp': 'IND'},
#   'tyrese haliburton': {'team': 'indiana pacers',
#    'line': '18.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-117'},
#    'opp': 'MEM'},
#   'pascal siakam': {'team': 'indiana pacers',
#    'line': '22.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-110'},
#    'opp': 'MEM'},
#   'luke kennard': {'team': 'memphis grizzlies',
#    'line': '6.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-118'},
#    'opp': 'IND'},
#   'tj mcconnell': {'team': 'indiana pacers',
#    'line': '11.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-108'},
#    'opp': 'MEM'},
#   'isaiah jackson': {'team': 'memphis grizzlies',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'MEM'},
#   'andrew nembhard': {'team': 'memphis grizzlies',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'MEM'}},
#  {'caris levert': {'team': 'cleveland cavaliers',
#    'line': '9.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'BOS'},
#   'jaylen brown': {'team': 'boston celtics',
#    'line': '24.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'CLE'},
#   'donovan mitchell': {'team': 'cleveland cavaliers',
#    'line': '26.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-119'},
#    'opp': 'BOS'},
#   'kristaps porzingis': {'team': 'boston celtics',
#    'line': '16.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-116'},
#    'opp': 'CLE'},
#   'georges niang': {'team': 'cleveland cavaliers',
#    'line': '8.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-108'},
#    'opp': 'BOS'},
#   'sam merrill': {'team': 'cleveland cavaliers',
#    'line': '6',
#    'over': {'book_line': '-138'},
#    'under': {'book_line': '+100'},
#    'opp': 'BOS'},
#   'ty jerome': {'team': 'cleveland cavaliers',
#    'line': '8.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-125'},
#    'opp': 'BOS'},
#   'darius garland': {'team': 'cleveland cavaliers',
#    'line': '19.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-117'},
#    'opp': 'BOS'},
#   'isaac okoro': {'team': 'cleveland cavaliers',
#    'line': '6.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-123'},
#    'opp': 'BOS'},
#   'evan mobley': {'team': 'cleveland cavaliers',
#    'line': '16.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-125'},
#    'opp': 'BOS'},
#   'derrick white': {'team': 'boston celtics',
#    'line': '16.5',
#    'over': {'book_line': '-124'},
#    'under': {'book_line': '-109'},
#    'opp': 'CLE'},
#   'jarrett allen': {'team': 'cleveland cavaliers',
#    'line': '12.5',
#    'over': {'book_line': '-136'},
#    'under': {'book_line': '+100'},
#    'opp': 'BOS'},
#   'jrue holiday': {'team': 'boston celtics',
#    'line': '11.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-103'},
#    'opp': 'CLE'},
#   'jayson tatum': {'team': 'boston celtics',
#    'line': '27.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-118'},
#    'opp': 'CLE'}},
#  {'haywood highsmith': {'team': 'miami heat',
#    'line': '5.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-120'},
#    'opp': 'TOR'},
#   'chris boucher': {'team': 'toronto raptors',
#    'line': '7.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'MIA'},
#   'terry rozier': {'team': 'miami heat',
#    'line': '10.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'TOR'},
#   'ochai agbaji': {'team': 'toronto raptors',
#    'line': '9.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'},
#    'opp': 'MIA'},
#   'rj barrett': {'team': 'toronto raptors',
#    'line': '23.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'},
#    'opp': 'MIA'},
#   'davion mitchell': {'team': 'toronto raptors',
#    'line': '5.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-114'},
#    'opp': 'MIA'},
#   'tyler herro': {'team': 'miami heat',
#    'line': '22.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-117'},
#    'opp': 'TOR'},
#   'bam adebayo': {'team': 'miami heat',
#    'line': '17.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'},
#    'opp': 'TOR'},
#   'scottie barnes': {'team': 'toronto raptors',
#    'line': '22.5',
#    'over': {'book_line': '-124'},
#    'under': {'book_line': '-110'},
#    'opp': 'MIA'},
#   'jimmy butler': {'team': 'miami heat',
#    'line': '19.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-113'},
#    'opp': 'TOR'},
#   'jaime jaquez jr': {'team': 'miami heat',
#    'line': '9.5',
#    'over': {'book_line': '-107'},
#    'under': {'book_line': '-123'},
#    'opp': 'TOR'},
#   'duncan robinson': {'team': 'miami heat',
#    'line': '11.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-117'},
#    'opp': 'TOR'},
#   'jakob poeltl': {'team': 'toronto raptors',
#    'line': '14.5',
#    'over': {'book_line': '-128'},
#    'under': {'book_line': '-103'},
#    'opp': 'MIA'},
#   'jakobe walter': {'team': 'toronto raptors',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'MIA'}},
#  {'jeremiah robinsonearl': {'team': 'new orleans pelicans',
#    'line': '6.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'NYK'},
#   'miles mcbride': {'team': 'new york knicks',
#    'line': '9.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '-104'},
#    'opp': 'NOP'},
#   'josh hart': {'team': 'new york knicks',
#    'line': '13.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-107'},
#    'opp': 'NOP'},
#   'trey murphy': {'team': 'new orleans pelicans',
#    'line': '19.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-115'},
#    'opp': 'NYK'},
#   'jalen brunson': {'team': 'new york knicks',
#    'line': '26.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-119'},
#    'opp': 'NOP'},
#   'dejounte murray': {'team': 'new orleans pelicans',
#    'line': '19.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'NYK'},
#   'og anunoby': {'team': 'new york knicks',
#    'line': '17.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-109'},
#    'opp': 'NOP'},
#   'cj mccollum': {'team': 'new orleans pelicans',
#    'line': '20.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-109'},
#    'opp': 'NYK'},
#   'yves missi': {'team': 'new orleans pelicans',
#    'line': '9.5',
#    'over': {'book_line': '-121'},
#    'under': {'book_line': '-108'},
#    'opp': 'NYK'},
#   'mikal bridges': {'team': 'new york knicks',
#    'line': '15.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-113'},
#    'opp': 'NOP'}},
#  {'shai gilgeousalexander': {'team': 'oklahoma city thunder',
#    'line': '30.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'},
#    'opp': 'HOU'},
#   'jalen williams': {'team': 'oklahoma city thunder',
#    'line': '21.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-120'},
#    'opp': 'HOU'},
#   'dillon brooks': {'team': 'houston rockets',
#    'line': '12.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-118'},
#    'opp': 'OKC'},
#   'isaiah hartenstein': {'team': 'oklahoma city thunder',
#    'line': '11.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'HOU'},
#   'tari eason': {'team': 'houston rockets',
#    'line': '11.5',
#    'over': {'book_line': '-123'},
#    'under': {'book_line': '-106'},
#    'opp': 'OKC'},
#   'amen thompson': {'team': 'houston rockets',
#    'line': '12.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-109'},
#    'opp': 'OKC'},
#   'jeenathan williams': {'team': 'houston rockets',
#    'line': '21.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-120'}},
#   'jabari smith': {'team': 'houston rockets',
#    'line': '11.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-105'},
#    'opp': 'OKC'},
#   'luguentz dort': {'team': 'oklahoma city thunder',
#    'line': '10',
#    'over': {'book_line': '-131'},
#    'under': {'book_line': '+100'},
#    'opp': 'HOU'},
#   'alperen sengun': {'team': 'houston rockets',
#    'line': '19.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-120'},
#    'opp': 'OKC'},
#   'fred vanvleet': {'team': 'houston rockets',
#    'line': '16.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-115'},
#    'opp': 'OKC'},
#   'jalen green': {'team': 'houston rockets',
#    'line': '17.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'OKC'},
#   'nate williams': {'team': 'oklahoma city thunder',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'OKC'},
#   'cason wallace': {'team': 'oklahoma city thunder',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'HOU'}},
#  {'austin reaves': {'team': 'los angeles lakers',
#    'line': '17.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'UTA'},
#   'keyonte george': {'team': 'utah jazz',
#    'line': '14.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-105'},
#    'opp': 'LAL'},
#   'walker kessler': {'team': 'utah jazz',
#    'line': '8.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-119'},
#    'opp': 'LAL'},
#   'lauri markkanen': {'team': 'utah jazz',
#    'line': '21.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-120'},
#    'opp': 'LAL'},
#   'collin sexton': {'team': 'utah jazz',
#    'line': '18.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-122'},
#    'opp': 'LAL'},
#   'john collins': {'team': 'utah jazz',
#    'line': '16.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'},
#    'opp': 'LAL'},
#   'lebron james': {'team': 'los angeles lakers',
#    'line': '24.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-112'},
#    'opp': 'UTA'},
#   'anthony davis': {'team': 'los angeles lakers',
#    'line': '28',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-110'},
#    'opp': 'UTA'},
#   'dalton knecht': {'team': 'utah jazz',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'UTA'},
#   'rui hachimura': {'team': 'utah jazz',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'UTA'}},
#  {'keldon johnson': {'team': 'san antonio spurs',
#    'line': '10.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'SAC'},
#   'tre jones': {'team': 'san antonio spurs',
#    'line': '4.5',
#    'over': {'book_line': '-127'},
#    'under': {'book_line': '-110'},
#    'opp': 'SAC'},
#   'harrison barnes': {'team': 'sacramento kings',
#    'line': '11.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-129'},
#    'opp': 'SAS'},
#   'deaaron fox': {'team': 'sacramento kings',
#    'line': '26.5',
#    'over': {'book_line': '-127'},
#    'under': {'book_line': '-105'},
#    'opp': 'SAS'},
#   'julian champagnie': {'team': 'san antonio spurs',
#    'line': '12.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-121'},
#    'opp': 'SAC'},
#   'malik monk': {'team': 'sacramento kings',
#    'line': '14.5',
#    'over': {'book_line': '+100'},
#    'under': {'book_line': '-132'},
#    'opp': 'SAS'},
#   'keon ellis': {'team': 'sacramento kings',
#    'line': '7.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-127'},
#    'opp': 'SAS'},
#   'domantas sabonis': {'team': 'sacramento kings',
#    'line': '18.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '-104'},
#    'opp': 'SAS'},
#   'victor wembanyama': {'team': 'san antonio spurs',
#    'line': '23.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-115'},
#    'opp': 'SAC'},
#   'colby jones': {'team': 'sacramento kings',
#    'line': '4.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-107'},
#    'opp': 'SAS'},
#   'devin vassell': {'team': 'san antonio spurs',
#    'line': '14.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-115'},
#    'opp': 'SAC'},
#   'keegan murray': {'team': 'sacramento kings',
#    'line': '12.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'SAS'},
#   'chris paul': {'team': 'san antonio spurs',
#    'line': '8.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-117'},
#    'opp': 'SAC'},
#   'stephon castle': {'team': 'san antonio spurs',
#    'line': '13.5',
#    'over': {'book_line': '-107'},
#    'under': {'book_line': '-125'},
#    'opp': 'SAC'}},
#  {'luka doncic': {'team': 'dallas mavericks',
#    'line': '27.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-120'},
#    'opp': 'POR'},
#   'anfernee simons': {'team': 'portland trail blazers',
#    'line': '19.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-120'},
#    'opp': 'DAL'},
#   'toumani camara': {'team': 'portland trail blazers',
#    'line': '9.5',
#    'over': {'book_line': '-102'},
#    'under': {'book_line': '-128'},
#    'opp': 'DAL'},
#   'shaedon sharpe': {'team': 'portland trail blazers',
#    'line': '17.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-111'},
#    'opp': 'DAL'},
#   'deandre ayton': {'team': 'portland trail blazers',
#    'line': '16.5',
#    'over': {'book_line': '-103'},
#    'under': {'book_line': '-130'},
#    'opp': 'DAL'},
#   'jerami grant': {'team': 'portland trail blazers',
#    'line': '14.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'DAL'},
#   'kyrie irving': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'dereck lively': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'deni avdija': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DAL'},
#   'pj washington': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'naji marshall': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'klay thompson': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'POR'},
#   'scoot henderson': {'team': 'portland trail blazers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DAL'}},
#  {'jamal murray': {'team': 'denver nuggets',
#    'line': '18.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'},
#    'opp': 'LAC'},
#   'kai jones': {'team': 'la clippers',
#    'line': '10.5',
#    'over': {'book_line': '-136'},
#    'under': {'book_line': '+100'},
#    'opp': 'DEN'},
#   'julian strawther': {'team': 'denver nuggets',
#    'line': '7',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'},
#    'opp': 'LAC'},
#   'michael porter jr': {'team': 'denver nuggets',
#    'line': '18.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-120'},
#    'opp': 'LAC'},
#   'ivica zubac': {'team': 'la clippers',
#    'line': '16.5',
#    'over': {'book_line': '-102'},
#    'under': {'book_line': '-129'},
#    'opp': 'DEN'},
#   'james harden': {'team': 'la clippers',
#    'line': '22.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-118'},
#    'opp': 'DEN'},
#   'peyton watson': {'team': 'denver nuggets',
#    'line': '9.5',
#    'over': {'book_line': '-103'},
#    'under': {'book_line': '-129'},
#    'opp': 'LAC'},
#   'nikola jokic': {'team': 'denver nuggets',
#    'line': '28.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-112'},
#    'opp': 'LAC'},
#   'russell westbrook': {'team': 'la clippers',
#    'line': '11.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-103'},
#    'opp': 'DEN'},
#   'christian braun': {'team': 'denver nuggets',
#    'line': '14.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-106'},
#    'opp': 'LAC'},
#   'norman powell': {'team': 'la clippers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DEN'},
#   'amir coffey': {'team': 'la clippers',
#    'line': None,
#    'over': {'odds': None, 'book_line': None},
#    'under': {'odds': None, 'book_line': None},
#    'opp': 'DEN'}}]

# %%
for d in game_data:
    print(d)
# Out:
# {'jonathan isaac': {'team': 'orlando magic', 'line': '6.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-118'}, 'opp': 'BKN'}, 'cameron johnson': {'team': 'brooklyn nets', 'line': '17.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-125'}, 'opp': 'ORL'}, 'anthony black': {'team': 'orlando magic', 'line': '7.5', 'over': {'book_line': '-130'}, 'under': {'book_line': '+100'}, 'opp': 'BKN'}, 'franz wagner': {'team': 'orlando magic', 'line': '26.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'BKN'}, 'moritz wagner': {'team': 'orlando magic', 'line': '11.5', 'over': {'book_line': '-117'}, 'under': {'book_line': '-111'}, 'opp': 'BKN'}, 'ben simmons': {'team': 'brooklyn nets', 'line': '6', 'over': {'book_line': '-141'}, 'under': {'book_line': '+105'}, 'opp': 'ORL'}, 'goga bitadze': {'team': 'orlando magic', 'line': '8.5', 'over': {'book_line': '-102'}, 'under': {'book_line': '-130'}, 'opp': 'BKN'}, 'dennis schroder': {'team': 'brooklyn nets', 'line': '18.5', 'over': {'book_line': '-122'}, 'under': {'book_line': '-109'}, 'opp': 'ORL'}, 'jalen suggs': {'team': 'orlando magic', 'line': '16.5', 'over': {'book_line': '-104'}, 'under': {'book_line': '-128'}, 'opp': 'BKN'}, 'wendell carter jr': {'team': 'orlando magic', 'line': '9.5', 'over': {'book_line': '-133'}, 'under': {'book_line': '+100'}, 'opp': 'BKN'}}
# {'jaren jackson jr': {'team': 'memphis grizzlies', 'line': '20.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'IND'}, 'myles turner': {'team': 'indiana pacers', 'line': '15.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-125'}, 'opp': 'MEM'}, 'bennedict mathurin': {'team': 'indiana pacers', 'line': '19.5', 'over': {'book_line': '-120'}, 'under': {'book_line': '-110'}, 'opp': 'MEM'}, 'jake laravia': {'team': 'memphis grizzlies', 'line': '5.5', 'over': {'book_line': '-116'}, 'under': {'book_line': '-115'}, 'opp': 'IND'}, 'ja morant': {'team': 'memphis grizzlies', 'line': '22.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'IND'}, 'gg jackson': {'team': 'memphis grizzlies', 'line': '20.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-118'}, 'opp': 'IND'}, 'brandon clarke': {'team': 'memphis grizzlies', 'line': '8.5', 'over': {'book_line': '-145'}, 'under': {'book_line': '+109'}, 'opp': 'IND'}, 'scotty pippen': {'team': 'memphis grizzlies', 'line': '6.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-106'}, 'opp': 'IND'}, 'desmond bane': {'team': 'memphis grizzlies', 'line': '15.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'IND'}, 'marcus smart': {'team': 'memphis grizzlies', 'line': '9.5', 'over': {'book_line': '-129'}, 'under': {'book_line': '-102'}, 'opp': 'IND'}, 'obi toppin': {'team': 'indiana pacers', 'line': '7.5', 'over': {'book_line': '-111'}, 'under': {'book_line': '-118'}, 'opp': 'MEM'}, 'santi aldama': {'team': 'memphis grizzlies', 'line': '9.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-122'}, 'opp': 'IND'}, 'tyrese haliburton': {'team': 'indiana pacers', 'line': '18.5', 'over': {'book_line': '-114'}, 'under': {'book_line': '-117'}, 'opp': 'MEM'}, 'pascal siakam': {'team': 'indiana pacers', 'line': '22.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-110'}, 'opp': 'MEM'}, 'luke kennard': {'team': 'memphis grizzlies', 'line': '6.5', 'over': {'book_line': '-114'}, 'under': {'book_line': '-118'}, 'opp': 'IND'}, 'tj mcconnell': {'team': 'indiana pacers', 'line': '11.5', 'over': {'book_line': '-120'}, 'under': {'book_line': '-108'}, 'opp': 'MEM'}, 'isaiah jackson': {'team': 'memphis grizzlies', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'MEM'}, 'andrew nembhard': {'team': 'memphis grizzlies', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'MEM'}}
# {'caris levert': {'team': 'cleveland cavaliers', 'line': '9.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'BOS'}, 'jaylen brown': {'team': 'boston celtics', 'line': '24.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'CLE'}, 'donovan mitchell': {'team': 'cleveland cavaliers', 'line': '26.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-119'}, 'opp': 'BOS'}, 'kristaps porzingis': {'team': 'boston celtics', 'line': '16.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-116'}, 'opp': 'CLE'}, 'georges niang': {'team': 'cleveland cavaliers', 'line': '8.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-108'}, 'opp': 'BOS'}, 'sam merrill': {'team': 'cleveland cavaliers', 'line': '6', 'over': {'book_line': '-138'}, 'under': {'book_line': '+100'}, 'opp': 'BOS'}, 'ty jerome': {'team': 'cleveland cavaliers', 'line': '8.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-125'}, 'opp': 'BOS'}, 'darius garland': {'team': 'cleveland cavaliers', 'line': '19.5', 'over': {'book_line': '-114'}, 'under': {'book_line': '-117'}, 'opp': 'BOS'}, 'isaac okoro': {'team': 'cleveland cavaliers', 'line': '6.5', 'over': {'book_line': '-109'}, 'under': {'book_line': '-123'}, 'opp': 'BOS'}, 'evan mobley': {'team': 'cleveland cavaliers', 'line': '16.5', 'over': {'book_line': '-111'}, 'under': {'book_line': '-125'}, 'opp': 'BOS'}, 'derrick white': {'team': 'boston celtics', 'line': '16.5', 'over': {'book_line': '-124'}, 'under': {'book_line': '-109'}, 'opp': 'CLE'}, 'jarrett allen': {'team': 'cleveland cavaliers', 'line': '12.5', 'over': {'book_line': '-136'}, 'under': {'book_line': '+100'}, 'opp': 'BOS'}, 'jrue holiday': {'team': 'boston celtics', 'line': '11.5', 'over': {'book_line': '-129'}, 'under': {'book_line': '-103'}, 'opp': 'CLE'}, 'jayson tatum': {'team': 'boston celtics', 'line': '27.5', 'over': {'book_line': '-113'}, 'under': {'book_line': '-118'}, 'opp': 'CLE'}}
# {'haywood highsmith': {'team': 'miami heat', 'line': '5.5', 'over': {'book_line': '-113'}, 'under': {'book_line': '-120'}, 'opp': 'TOR'}, 'chris boucher': {'team': 'toronto raptors', 'line': '7.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'MIA'}, 'terry rozier': {'team': 'miami heat', 'line': '10.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'TOR'}, 'ochai agbaji': {'team': 'toronto raptors', 'line': '9.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-125'}, 'opp': 'MIA'}, 'rj barrett': {'team': 'toronto raptors', 'line': '23.5', 'over': {'book_line': '-105'}, 'under': {'book_line': '-125'}, 'opp': 'MIA'}, 'davion mitchell': {'team': 'toronto raptors', 'line': '5.5', 'over': {'book_line': '-117'}, 'under': {'book_line': '-114'}, 'opp': 'MIA'}, 'tyler herro': {'team': 'miami heat', 'line': '22.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-117'}, 'opp': 'TOR'}, 'bam adebayo': {'team': 'miami heat', 'line': '17.5', 'over': {'book_line': '-105'}, 'under': {'book_line': '-125'}, 'opp': 'TOR'}, 'scottie barnes': {'team': 'toronto raptors', 'line': '22.5', 'over': {'book_line': '-124'}, 'under': {'book_line': '-110'}, 'opp': 'MIA'}, 'jimmy butler': {'team': 'miami heat', 'line': '19.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-113'}, 'opp': 'TOR'}, 'jaime jaquez jr': {'team': 'miami heat', 'line': '9.5', 'over': {'book_line': '-107'}, 'under': {'book_line': '-123'}, 'opp': 'TOR'}, 'duncan robinson': {'team': 'miami heat', 'line': '11.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-117'}, 'opp': 'TOR'}, 'jakob poeltl': {'team': 'toronto raptors', 'line': '14.5', 'over': {'book_line': '-128'}, 'under': {'book_line': '-103'}, 'opp': 'MIA'}, 'jakobe walter': {'team': 'toronto raptors', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'MIA'}}
# {'jeremiah robinsonearl': {'team': 'new orleans pelicans', 'line': '6.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'NYK'}, 'miles mcbride': {'team': 'new york knicks', 'line': '9.5', 'over': {'book_line': '-130'}, 'under': {'book_line': '-104'}, 'opp': 'NOP'}, 'josh hart': {'team': 'new york knicks', 'line': '13.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-107'}, 'opp': 'NOP'}, 'trey murphy': {'team': 'new orleans pelicans', 'line': '19.5', 'over': {'book_line': '-119'}, 'under': {'book_line': '-115'}, 'opp': 'NYK'}, 'jalen brunson': {'team': 'new york knicks', 'line': '26.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-119'}, 'opp': 'NOP'}, 'dejounte murray': {'team': 'new orleans pelicans', 'line': '19.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'NYK'}, 'og anunoby': {'team': 'new york knicks', 'line': '17.5', 'over': {'book_line': '-122'}, 'under': {'book_line': '-109'}, 'opp': 'NOP'}, 'cj mccollum': {'team': 'new orleans pelicans', 'line': '20.5', 'over': {'book_line': '-122'}, 'under': {'book_line': '-109'}, 'opp': 'NYK'}, 'yves missi': {'team': 'new orleans pelicans', 'line': '9.5', 'over': {'book_line': '-121'}, 'under': {'book_line': '-108'}, 'opp': 'NYK'}, 'mikal bridges': {'team': 'new york knicks', 'line': '15.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-113'}, 'opp': 'NOP'}}
# {'shai gilgeousalexander': {'team': 'oklahoma city thunder', 'line': '30.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-118'}, 'opp': 'HOU'}, 'jalen williams': {'team': 'oklahoma city thunder', 'line': '21.5', 'over': {'book_line': '-109'}, 'under': {'book_line': '-120'}, 'opp': 'HOU'}, 'dillon brooks': {'team': 'houston rockets', 'line': '12.5', 'over': {'book_line': '-112'}, 'under': {'book_line': '-118'}, 'opp': 'OKC'}, 'isaiah hartenstein': {'team': 'oklahoma city thunder', 'line': '11.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'HOU'}, 'tari eason': {'team': 'houston rockets', 'line': '11.5', 'over': {'book_line': '-123'}, 'under': {'book_line': '-106'}, 'opp': 'OKC'}, 'amen thompson': {'team': 'houston rockets', 'line': '12.5', 'over': {'book_line': '-120'}, 'under': {'book_line': '-109'}, 'opp': 'OKC'}, 'jeenathan williams': {'team': 'houston rockets', 'line': '21.5', 'over': {'book_line': '-108'}, 'under': {'book_line': '-120'}}, 'jabari smith': {'team': 'houston rockets', 'line': '11.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-105'}, 'opp': 'OKC'}, 'luguentz dort': {'team': 'oklahoma city thunder', 'line': '10', 'over': {'book_line': '-131'}, 'under': {'book_line': '+100'}, 'opp': 'HOU'}, 'alperen sengun': {'team': 'houston rockets', 'line': '19.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-120'}, 'opp': 'OKC'}, 'fred vanvleet': {'team': 'houston rockets', 'line': '16.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-115'}, 'opp': 'OKC'}, 'jalen green': {'team': 'houston rockets', 'line': '17.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'OKC'}, 'nate williams': {'team': 'oklahoma city thunder', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'OKC'}, 'cason wallace': {'team': 'oklahoma city thunder', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'HOU'}}
# {'austin reaves': {'team': 'los angeles lakers', 'line': '17.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'UTA'}, 'keyonte george': {'team': 'utah jazz', 'line': '14.5', 'over': {'book_line': '-129'}, 'under': {'book_line': '-105'}, 'opp': 'LAL'}, 'walker kessler': {'team': 'utah jazz', 'line': '8.5', 'over': {'book_line': '-113'}, 'under': {'book_line': '-119'}, 'opp': 'LAL'}, 'lauri markkanen': {'team': 'utah jazz', 'line': '21.5', 'over': {'book_line': '-111'}, 'under': {'book_line': '-120'}, 'opp': 'LAL'}, 'collin sexton': {'team': 'utah jazz', 'line': '18.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-122'}, 'opp': 'LAL'}, 'john collins': {'team': 'utah jazz', 'line': '16.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-118'}, 'opp': 'LAL'}, 'lebron james': {'team': 'los angeles lakers', 'line': '24.5', 'over': {'book_line': '-119'}, 'under': {'book_line': '-112'}, 'opp': 'UTA'}, 'anthony davis': {'team': 'los angeles lakers', 'line': '28', 'over': {'book_line': '-125'}, 'under': {'book_line': '-110'}, 'opp': 'UTA'}, 'dalton knecht': {'team': 'utah jazz', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'UTA'}, 'rui hachimura': {'team': 'utah jazz', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'UTA'}}
# {'keldon johnson': {'team': 'san antonio spurs', 'line': '10.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'SAC'}, 'tre jones': {'team': 'san antonio spurs', 'line': '4.5', 'over': {'book_line': '-127'}, 'under': {'book_line': '-110'}, 'opp': 'SAC'}, 'harrison barnes': {'team': 'sacramento kings', 'line': '11.5', 'over': {'book_line': '-105'}, 'under': {'book_line': '-129'}, 'opp': 'SAS'}, 'deaaron fox': {'team': 'sacramento kings', 'line': '26.5', 'over': {'book_line': '-127'}, 'under': {'book_line': '-105'}, 'opp': 'SAS'}, 'julian champagnie': {'team': 'san antonio spurs', 'line': '12.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-121'}, 'opp': 'SAC'}, 'malik monk': {'team': 'sacramento kings', 'line': '14.5', 'over': {'book_line': '+100'}, 'under': {'book_line': '-132'}, 'opp': 'SAS'}, 'keon ellis': {'team': 'sacramento kings', 'line': '7.5', 'over': {'book_line': '-108'}, 'under': {'book_line': '-127'}, 'opp': 'SAS'}, 'domantas sabonis': {'team': 'sacramento kings', 'line': '18.5', 'over': {'book_line': '-130'}, 'under': {'book_line': '-104'}, 'opp': 'SAS'}, 'victor wembanyama': {'team': 'san antonio spurs', 'line': '23.5', 'over': {'book_line': '-117'}, 'under': {'book_line': '-115'}, 'opp': 'SAC'}, 'colby jones': {'team': 'sacramento kings', 'line': '4.5', 'over': {'book_line': '-122'}, 'under': {'book_line': '-107'}, 'opp': 'SAS'}, 'devin vassell': {'team': 'san antonio spurs', 'line': '14.5', 'over': {'book_line': '-117'}, 'under': {'book_line': '-115'}, 'opp': 'SAC'}, 'keegan murray': {'team': 'sacramento kings', 'line': '12.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'SAS'}, 'chris paul': {'team': 'san antonio spurs', 'line': '8.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-117'}, 'opp': 'SAC'}, 'stephon castle': {'team': 'san antonio spurs', 'line': '13.5', 'over': {'book_line': '-107'}, 'under': {'book_line': '-125'}, 'opp': 'SAC'}}
# {'luka doncic': {'team': 'dallas mavericks', 'line': '27.5', 'over': {'book_line': '-109'}, 'under': {'book_line': '-120'}, 'opp': 'POR'}, 'anfernee simons': {'team': 'portland trail blazers', 'line': '19.5', 'over': {'book_line': '-108'}, 'under': {'book_line': '-120'}, 'opp': 'DAL'}, 'toumani camara': {'team': 'portland trail blazers', 'line': '9.5', 'over': {'book_line': '-102'}, 'under': {'book_line': '-128'}, 'opp': 'DAL'}, 'shaedon sharpe': {'team': 'portland trail blazers', 'line': '17.5', 'over': {'book_line': '-119'}, 'under': {'book_line': '-111'}, 'opp': 'DAL'}, 'deandre ayton': {'team': 'portland trail blazers', 'line': '16.5', 'over': {'book_line': '-103'}, 'under': {'book_line': '-130'}, 'opp': 'DAL'}, 'jerami grant': {'team': 'portland trail blazers', 'line': '14.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'DAL'}, 'kyrie irving': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}, 'dereck lively': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}, 'deni avdija': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DAL'}, 'pj washington': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}, 'naji marshall': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}, 'klay thompson': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}, 'scoot henderson': {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DAL'}}
# {'jamal murray': {'team': 'denver nuggets', 'line': '18.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'LAC'}, 'kai jones': {'team': 'la clippers', 'line': '10.5', 'over': {'book_line': '-136'}, 'under': {'book_line': '+100'}, 'opp': 'DEN'}, 'julian strawther': {'team': 'denver nuggets', 'line': '7', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'LAC'}, 'michael porter jr': {'team': 'denver nuggets', 'line': '18.5', 'over': {'book_line': '-112'}, 'under': {'book_line': '-120'}, 'opp': 'LAC'}, 'ivica zubac': {'team': 'la clippers', 'line': '16.5', 'over': {'book_line': '-102'}, 'under': {'book_line': '-129'}, 'opp': 'DEN'}, 'james harden': {'team': 'la clippers', 'line': '22.5', 'over': {'book_line': '-113'}, 'under': {'book_line': '-118'}, 'opp': 'DEN'}, 'peyton watson': {'team': 'denver nuggets', 'line': '9.5', 'over': {'book_line': '-103'}, 'under': {'book_line': '-129'}, 'opp': 'LAC'}, 'nikola jokic': {'team': 'denver nuggets', 'line': '28.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-112'}, 'opp': 'LAC'}, 'russell westbrook': {'team': 'la clippers', 'line': '11.5', 'over': {'book_line': '-129'}, 'under': {'book_line': '-103'}, 'opp': 'DEN'}, 'christian braun': {'team': 'denver nuggets', 'line': '14.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-106'}, 'opp': 'LAC'}, 'norman powell': {'team': 'la clippers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DEN'}, 'amir coffey': {'team': 'la clippers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DEN'}}

# %%
date = datetime.now().date().strftime('%Y/%m/%d') 
for d in game_data:
    for player in d:
        print(player)
        
        # Create a column for the player if it doesn't exist
        if f'{player}_line' not in df.columns:
            df[f'{player}_line'] = np.nan
        if f'{player}_under' not in df.columns:
            df[f'{player}_under'] = np.nan
        if f'{player}_over' not in df.columns:
            df[f'{player}_over'] = np.nan
        
        
        # Find the first NaN value in the player's column
    
        print(date)
        # Assign the new value to the next empty row
        df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
        df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
        df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
        print(d[player])
        if player == "jeenathan williams":
            continue
        df.loc[df['date'] == date, f'{player}_todays_game'] = d[player]['opp']
# Out:
# jonathan isaac
# 2024/12/01
# {'team': 'orlando magic', 'line': '6.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-118'}, 'opp': 'BKN'}
# cameron johnson
# 2024/12/01
# {'team': 'brooklyn nets', 'line': '17.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-125'}, 'opp': 'ORL'}
# anthony black
# 2024/12/01
# {'team': 'orlando magic', 'line': '7.5', 'over': {'book_line': '-130'}, 'under': {'book_line': '+100'}, 'opp': 'BKN'}
# franz wagner
# 2024/12/01
# {'team': 'orlando magic', 'line': '26.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'BKN'}
# moritz wagner
# 2024/12/01
# {'team': 'orlando magic', 'line': '11.5', 'over': {'book_line': '-117'}, 'under': {'book_line': '-111'}, 'opp': 'BKN'}
# ben simmons
# 2024/12/01
# {'team': 'brooklyn nets', 'line': '6', 'over': {'book_line': '-141'}, 'under': {'book_line': '+105'}, 'opp': 'ORL'}
# goga bitadze
# 2024/12/01
# {'team': 'orlando magic', 'line': '8.5', 'over': {'book_line': '-102'}, 'under': {'book_line': '-130'}, 'opp': 'BKN'}
# dennis schroder
# 2024/12/01
# {'team': 'brooklyn nets', 'line': '18.5', 'over': {'book_line': '-122'}, 'under': {'book_line': '-109'}, 'opp': 'ORL'}
# jalen suggs
# 2024/12/01
# {'team': 'orlando magic', 'line': '16.5', 'over': {'book_line': '-104'}, 'under': {'book_line': '-128'}, 'opp': 'BKN'}
# wendell carter jr
# 2024/12/01
# {'team': 'orlando magic', 'line': '9.5', 'over': {'book_line': '-133'}, 'under': {'book_line': '+100'}, 'opp': 'BKN'}
# jaren jackson jr
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '20.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'IND'}
# myles turner
# 2024/12/01
# {'team': 'indiana pacers', 'line': '15.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-125'}, 'opp': 'MEM'}
# bennedict mathurin
# 2024/12/01
# {'team': 'indiana pacers', 'line': '19.5', 'over': {'book_line': '-120'}, 'under': {'book_line': '-110'}, 'opp': 'MEM'}
# jake laravia
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '5.5', 'over': {'book_line': '-116'}, 'under': {'book_line': '-115'}, 'opp': 'IND'}
# ja morant
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '22.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'IND'}
# gg jackson
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '20.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-118'}, 'opp': 'IND'}
# brandon clarke
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '8.5', 'over': {'book_line': '-145'}, 'under': {'book_line': '+109'}, 'opp': 'IND'}
# scotty pippen
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '6.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-106'}, 'opp': 'IND'}
# desmond bane
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '15.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'IND'}
# marcus smart
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '9.5', 'over': {'book_line': '-129'}, 'under': {'book_line': '-102'}, 'opp': 'IND'}
# obi toppin
# 2024/12/01
# {'team': 'indiana pacers', 'line': '7.5', 'over': {'book_line': '-111'}, 'under': {'book_line': '-118'}, 'opp': 'MEM'}
# santi aldama
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '9.5', 'over': {'book_line': '-106'}, 'under': {'book_line': '-122'}, 'opp': 'IND'}
# tyrese haliburton
# 2024/12/01
# {'team': 'indiana pacers', 'line': '18.5', 'over': {'book_line': '-114'}, 'under': {'book_line': '-117'}, 'opp': 'MEM'}
# pascal siakam
# 2024/12/01
# {'team': 'indiana pacers', 'line': '22.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-110'}, 'opp': 'MEM'}
# luke kennard
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': '6.5', 'over': {'book_line': '-114'}, 'under': {'book_line': '-118'}, 'opp': 'IND'}
# tj mcconnell
# 2024/12/01
# {'team': 'indiana pacers', 'line': '11.5', 'over': {'book_line': '-120'}, 'under': {'book_line': '-108'}, 'opp': 'MEM'}
# isaiah jackson
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'MEM'}
# andrew nembhard
# 2024/12/01
# {'team': 'memphis grizzlies', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'MEM'}
# caris levert
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '9.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'BOS'}
# jaylen brown
# 2024/12/01
# {'team': 'boston celtics', 'line': '24.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'CLE'}
# donovan mitchell
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '26.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-119'}, 'opp': 'BOS'}
# kristaps porzingis
# 2024/12/01
# {'team': 'boston celtics', 'line': '16.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-116'}, 'opp': 'CLE'}
# georges niang
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '8.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-108'}, 'opp': 'BOS'}
# sam merrill
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '6', 'over': {'book_line': '-138'}, 'under': {'book_line': '+100'}, 'opp': 'BOS'}
# ty jerome
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '8.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-125'}, 'opp': 'BOS'}
# darius garland
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '19.5', 'over': {'book_line': '-114'}, 'under': {'book_line': '-117'}, 'opp': 'BOS'}
# isaac okoro
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '6.5', 'over': {'book_line': '-109'}, 'under': {'book_line': '-123'}, 'opp': 'BOS'}
# evan mobley
# 2024/12/01
# {'team': 'cleveland cavaliers', 'line': '16.5', 'over': {'book_line': '-111'}, 'under': {'book_line': '-125'}, 'opp': 'BOS'}
# derrick white
# 2024/12/01
# {'team': 'boston celtics', 'line': '16.5', 'over': {'book_line': '-124'}, 'under': {'book_line': '-109'}, 'opp': 'CLE'}
# jarrett allen
# 2024/12/01
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '17.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-106' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-125' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-130' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+100' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-117' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-111' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-141' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+105' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-102' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-130' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-122' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-109' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-104' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-128' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-133' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+100' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-106' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-125' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-120' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-116' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-120' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '20.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-145' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+109' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-125' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-106' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-129' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-102' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-111' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-106' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-122' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-114' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-117' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-114' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-120' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-108' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-120' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['date'] == date, f'{player}_todays_game'] = d[player]['opp']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-120' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '26.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-119' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_line'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_under'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_over'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-116' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['date'] == date, f'{player}_todays_game'] = d[player]['opp']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-125' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-108' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['date'] == date, f'{player}_todays_game'] = d[player]['opp']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-138' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+100' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_line'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_under'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_over'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '8.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-110' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-125' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['date'] == date, f'{player}_todays_game'] = d[player]['opp']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '19.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-114' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-117' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '6.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-109' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# ...
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-136' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+100' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '7' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-115' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '18.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-112' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-120' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-102' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-129' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '22.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-113' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '9.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-103' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-129' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '28.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-118' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-112' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# colby jones
# 2024/12/01
# {'team': 'sacramento kings', 'line': '4.5', 'over': {'book_line': '-122'}, 'under': {'book_line': '-107'}, 'opp': 'SAS'}
# devin vassell
# 2024/12/01
# {'team': 'san antonio spurs', 'line': '14.5', 'over': {'book_line': '-117'}, 'under': {'book_line': '-115'}, 'opp': 'SAC'}
# keegan murray
# 2024/12/01
# {'team': 'sacramento kings', 'line': '12.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'SAS'}
# chris paul
# 2024/12/01
# {'team': 'san antonio spurs', 'line': '8.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-117'}, 'opp': 'SAC'}
# stephon castle
# 2024/12/01
# {'team': 'san antonio spurs', 'line': '13.5', 'over': {'book_line': '-107'}, 'under': {'book_line': '-125'}, 'opp': 'SAC'}
# luka doncic
# 2024/12/01
# {'team': 'dallas mavericks', 'line': '27.5', 'over': {'book_line': '-109'}, 'under': {'book_line': '-120'}, 'opp': 'POR'}
# anfernee simons
# 2024/12/01
# {'team': 'portland trail blazers', 'line': '19.5', 'over': {'book_line': '-108'}, 'under': {'book_line': '-120'}, 'opp': 'DAL'}
# toumani camara
# 2024/12/01
# {'team': 'portland trail blazers', 'line': '9.5', 'over': {'book_line': '-102'}, 'under': {'book_line': '-128'}, 'opp': 'DAL'}
# shaedon sharpe
# 2024/12/01
# {'team': 'portland trail blazers', 'line': '17.5', 'over': {'book_line': '-119'}, 'under': {'book_line': '-111'}, 'opp': 'DAL'}
# deandre ayton
# 2024/12/01
# {'team': 'portland trail blazers', 'line': '16.5', 'over': {'book_line': '-103'}, 'under': {'book_line': '-130'}, 'opp': 'DAL'}
# jerami grant
# 2024/12/01
# {'team': 'portland trail blazers', 'line': '14.5', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'DAL'}
# kyrie irving
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}
# dereck lively
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}
# deni avdija
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DAL'}
# pj washington
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}
# naji marshall
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}
# klay thompson
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'POR'}
# scoot henderson
# 2024/12/01
# {'team': 'portland trail blazers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DAL'}
# jamal murray
# 2024/12/01
# {'team': 'denver nuggets', 'line': '18.5', 'over': {'book_line': '-110'}, 'under': {'book_line': '-120'}, 'opp': 'LAC'}
# kai jones
# 2024/12/01
# {'team': 'la clippers', 'line': '10.5', 'over': {'book_line': '-136'}, 'under': {'book_line': '+100'}, 'opp': 'DEN'}
# julian strawther
# 2024/12/01
# {'team': 'denver nuggets', 'line': '7', 'over': {'book_line': '-115'}, 'under': {'book_line': '-115'}, 'opp': 'LAC'}
# michael porter jr
# 2024/12/01
# {'team': 'denver nuggets', 'line': '18.5', 'over': {'book_line': '-112'}, 'under': {'book_line': '-120'}, 'opp': 'LAC'}
# ivica zubac
# 2024/12/01
# {'team': 'la clippers', 'line': '16.5', 'over': {'book_line': '-102'}, 'under': {'book_line': '-129'}, 'opp': 'DEN'}
# james harden
# 2024/12/01
# {'team': 'la clippers', 'line': '22.5', 'over': {'book_line': '-113'}, 'under': {'book_line': '-118'}, 'opp': 'DEN'}
# peyton watson
# 2024/12/01
# {'team': 'denver nuggets', 'line': '9.5', 'over': {'book_line': '-103'}, 'under': {'book_line': '-129'}, 'opp': 'LAC'}
# nikola jokic
# 2024/12/01
# {'team': 'denver nuggets', 'line': '28.5', 'over': {'book_line': '-118'}, 'under': {'book_line': '-112'}, 'opp': 'LAC'}
# russell westbrook
# 2024/12/01
# {'team': 'la clippers', 'line': '11.5', 'over': {'book_line': '-129'}, 'under': {'book_line': '-103'}, 'opp': 'DEN'}
# christian braun
# 2024/12/01
# {'team': 'denver nuggets', 'line': '14.5', 'over': {'book_line': '-125'}, 'under': {'book_line': '-106'}, 'opp': 'LAC'}
# norman powell
# 2024/12/01
# {'team': 'la clippers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DEN'}
# amir coffey
# 2024/12/01
# {'team': 'la clippers', 'line': None, 'over': {'odds': None, 'book_line': None}, 'under': {'odds': None, 'book_line': None}, 'opp': 'DEN'}
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_under'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{player}_over'] = np.nan
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-129' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-103' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[df['date'] == date, f'{player}_todays_game'] = d[player]['opp']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:19: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-125' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
# C:\Users\jam2m\AppData\Local\Temp\ipykernel_9840\1649896088.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-106' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']

# %%
df = df.loc[:, ~df.columns.duplicated()]
df.shape
# Out:
# (1000, 1500)

# %%
df.columns = df.columns.str.lower()

# %%
# Define the patterns to match
patterns = ["new", "golden", "los", "oklahoma", "san", "portland"]
suffixes = ["over", "under", "line"]

# Create a regex pattern
pattern = '|'.join([f"{p}.*({s})" for p in patterns for s in suffixes])

# Drop columns that match the pattern
df_filtered = df.drop(columns=df.filter(regex=pattern).columns)

# %%
df_filtered.shape
# Out:
# (1000, 1497)

# %%
df_filtered.to_csv('prop_table.csv')

# %%
url = "https://api.sportsgameodds.com/v1/account/usage"

headers = header

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'success': True, 'data': {'keyID': 'b8d294d968b4d0f753d53f4a9e8173952107b1a17338a758b68f98f2ab887092', 'customerID': 'cus_RAwtHswGZQdPPj', 'isActive': True, 'rateLimits': {'per-second': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': 'n/a'}, 'per-minute': {'maxRequestsPerInterval': 10, 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 1, 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': '2024-12-01T17:27:14.004Z'}, 'per-hour': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': 'n/a'}, 'per-day': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': 'n/a'}, 'per-month': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 1000, 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 1, 'currentIntervalEndTime': '2025-01-01T00:00:00.000Z'}}}}
