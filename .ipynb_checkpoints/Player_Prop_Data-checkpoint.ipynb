# %% [markdown]
# # Accessing Odds API to gather Player Props data

# %%
import requests
import json
import pandas as pd
import re
import numpy as np
from datetime import datetime, timedelta

# %%
odds_key = '263a5283466a90bc48a0172a178d1247'

sports_key = '531d4958e32b2acc9e2319c2d43fceab'

# %%
header = {'x-api-key': sports_key}

# %%
today = datetime.today()
tomorrow = today + timedelta(days = 1)
yesterday = today - timedelta(days = 2)

# %%
response = requests.get('https://api.sportsgameodds.com/v1/events', params={
    'leagueID': 'NBA',
    'marketOddsAvailable': 'true',
    'limit': 30,
    'startsAfter': today,
    'startsBefore': tomorrow
}, headers = header)

data = response.json()

# %%
length = len(data['data'])

# %%
length
# Out:
# 11

# %%
def extract_player_point_props(json_data):
    player_props = {}
    pattern = r"points-([A-Z_]+)_NBA-game-ou-(over|under)"
    three_word_teams = ["new", "golden", "los", "oklahoma", "san"]

    for key, value in json_data['odds'].items():
        match = re.match(pattern, key)
        if match:
            full_name = match.group(1).replace('_', ' ').lower()
            over_under = match.group(2).lower()
            
            # Split the full name into parts
            name_parts = full_name.split()
            
            # Check if the third-to-last word is in the list of three-word team prefixes
            if len(name_parts) > 3 and name_parts[-3] in three_word_teams:
                player_name = ' '.join(name_parts[:-3])  # Everything except the last three words
                team_name = ' '.join(name_parts[-3:])    # Last three words
            else:
                player_name = ' '.join(name_parts[:-2])  # Everything except the last two words
                team_name = ' '.join(name_parts[-2:])    # Last two words
            
            if player_name not in player_props:
                player_props[player_name] = {
                    'team': team_name,
                    'line': value['overUnder'],
                    'over': {'odds': None, 'book_line': None},
                    'under': {'odds': None, 'book_line': None}
                }
            
            if value['sideID'].lower() == 'over':
                player_props[player_name]['over'] = {
                    'book_line': value['bookOdds']
                }
            elif value['sideID'].lower() == 'under':
                player_props[player_name]['under'] = {
                    'book_line': value['bookOdds']
                }

    return player_props

# %%
game_data = []
for i in range(length):
    d = extract_player_point_props(data['data'][i])
    game_data.append(d)

# %% [markdown]
# ### Below is commented out since only needed once

# %%
game_data
# Out:
# [{'franz wagner': {'team': 'orlando magic',
#    'line': '25.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-112'}},
#   'tyrese haliburton': {'team': 'indiana pacers',
#    'line': '19.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-113'}},
#   'bennedict mathurin': {'team': 'indiana pacers',
#    'line': '18.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'}},
#   'tristan da silva': {'team': 'orlando magic',
#    'line': '9.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-111'}},
#   'goga bitadze': {'team': 'orlando magic',
#    'line': '9.5',
#    'over': {'book_line': '-107'},
#    'under': {'book_line': '-125'}},
#   'jalen suggs': {'team': 'orlando magic',
#    'line': '17.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-107'}},
#   'myles turner': {'team': 'indiana pacers',
#    'line': '18.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'}},
#   'pascal siakam': {'team': 'indiana pacers',
#    'line': '21.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-119'}}},
#  {'luguentz dort': {'team': 'oklahoma city thunder',
#    'line': '13.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-125'}},
#   'trey murphy': {'team': 'new orleans pelicans',
#    'line': '14.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-104'}},
#   'shai gilgeousalexander': {'team': 'oklahoma city thunder',
#    'line': '30.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-114'}},
#   'jalen williams': {'team': 'oklahoma city thunder',
#    'line': '21.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-104'}},
#   'yves missi': {'team': 'new orleans pelicans',
#    'line': '7',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-115'}},
#   'brandon ingram': {'team': 'new orleans pelicans',
#    'line': '23.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-119'}}},
#  {'zach lavine': {'team': 'chicago bulls',
#    'line': '20.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-105'}},
#   'patrick williams': {'team': 'chicago bulls',
#    'line': '10.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-110'}},
#   'mikal bridges': {'team': 'new york knicks',
#    'line': '15.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-113'}},
#   'joshua giddey': {'team': 'chicago bulls',
#    'line': '12.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-123'}},
#   'ayo dosunmu': {'team': 'chicago bulls',
#    'line': '11.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-110'}},
#   'nikola vucevic': {'team': 'chicago bulls',
#    'line': '17.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-118'}},
#   'jalen brunson': {'team': 'new york knicks',
#    'line': '27.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'}},
#   'og anunoby': {'team': 'new york knicks',
#    'line': '16.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-119'}},
#   'miles mcbride': {'team': 'new york knicks',
#    'line': '11.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-118'}},
#   'josh hart': {'team': 'new york knicks',
#    'line': '13.5',
#    'over': {'book_line': '-117'},
#    'under': {'book_line': '-114'}},
#   'coby white': {'team': 'chicago bulls',
#    'line': '18.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-121'}}},
#  {'neemias queta': {'team': 'boston celtics',
#    'line': '7.5',
#    'over': {'book_line': '-124'},
#    'under': {'book_line': '-105'}},
#   'jrue holiday': {'team': 'boston celtics',
#    'line': '11.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-105'}},
#   'jaylen brown': {'team': 'boston celtics',
#    'line': '23.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-118'}},
#   'cam thomas': {'team': 'brooklyn nets',
#    'line': '23.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-111'}},
#   'jayson tatum': {'team': 'boston celtics',
#    'line': '27.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-110'}},
#   'dorian finneysmith': {'team': 'brooklyn nets',
#    'line': '8.5',
#    'over': {'book_line': '-137'},
#    'under': {'book_line': '+102'}},
#   'cameron johnson': {'team': 'brooklyn nets',
#    'line': '14.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-121'}},
#   'dennis schroder': {'team': 'brooklyn nets',
#    'line': '16.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-119'}},
#   'nic claxton': {'team': 'brooklyn nets',
#    'line': '10.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'}},
#   'derrick white': {'team': 'boston celtics',
#    'line': '16.5',
#    'over': {'book_line': '-103'},
#    'under': {'book_line': '-130'}}},
#  {'isaac okoro': {'team': 'cleveland cavaliers',
#    'line': '5.5',
#    'over': {'book_line': '-145'},
#    'under': {'book_line': '+100'}},
#   'evan mobley': {'team': 'cleveland cavaliers',
#    'line': '17.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'}},
#   'darius garland': {'team': 'cleveland cavaliers',
#    'line': '18.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'}},
#   'donovan mitchell': {'team': 'cleveland cavaliers',
#    'line': '24.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-111'}},
#   'jarrett allen': {'team': 'cleveland cavaliers',
#    'line': '12.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-120'}}},
#  {'brook lopez': {'team': 'milwaukee bucks',
#    'line': '12.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-119'}},
#   'jalen duren': {'team': 'detroit pistons',
#    'line': '9.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-123'}},
#   'jaden ivey': {'team': 'detroit pistons',
#    'line': '19.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-111'}},
#   'giannis antetokounmpo': {'team': 'milwaukee bucks',
#    'line': '33.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-111'}},
#   'tobias harris': {'team': 'detroit pistons',
#    'line': '14.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-120'}},
#   'cade cunningham': {'team': 'detroit pistons',
#    'line': '23.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-108'}}},
#  {'julian champagnie': {'team': 'san antonio spurs',
#    'line': '11.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'}},
#   'stephon castle': {'team': 'san antonio spurs',
#    'line': '12.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-125'}},
#   'chris paul': {'team': 'san antonio spurs',
#    'line': '9.5',
#    'over': {'book_line': '-116'},
#    'under': {'book_line': '-115'}},
#   'corey kispert': {'team': 'washington wizards',
#    'line': '12.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-110'}},
#   'jordan poole': {'team': 'washington wizards',
#    'line': '20.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-118'}},
#   'alexandre sarr': {'team': 'washington wizards',
#    'line': '9.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-118'}},
#   'kyle kuzma': {'team': 'washington wizards',
#    'line': '18.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-112'}},
#   'bilal coulibaly': {'team': 'washington wizards',
#    'line': '12.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-127'}},
#   'victor wembanyama': {'team': 'san antonio spurs',
#    'line': '24.5',
#    'over': {'book_line': '-129'},
#    'under': {'book_line': '-104'}}},
#  {'dillon brooks': {'team': 'houston rockets',
#    'line': '11.5',
#    'over': {'book_line': '-101'},
#    'under': {'book_line': '-133'}},
#   'terance mann': {'team': 'la clippers',
#    'line': '6.5',
#    'over': {'book_line': '-108'},
#    'under': {'book_line': '-125'}},
#   'alperen sengun': {'team': 'houston rockets',
#    'line': '19.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'}},
#   'fred vanvleet': {'team': 'houston rockets',
#    'line': '14.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-115'}},
#   'kai jones': {'team': 'la clippers',
#    'line': '8.5',
#    'over': {'book_line': '-111'},
#    'under': {'book_line': '-118'}},
#   'norman powell': {'team': 'la clippers',
#    'line': '21.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-120'}},
#   'ivica zubac': {'team': 'la clippers',
#    'line': '15.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-112'}},
#   'james harden': {'team': 'la clippers',
#    'line': '22.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'}},
#   'jalen green': {'team': 'houston rockets',
#    'line': '22.5',
#    'over': {'book_line': '-123'},
#    'under': {'book_line': '-108'}},
#   'jabari smith': {'team': 'houston rockets',
#    'line': '11.5',
#    'over': {'book_line': '-130'},
#    'under': {'book_line': '-104'}}},
#  {'nickeil alexanderwalker': {'team': 'minnesota timberwolves',
#    'line': '7.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-118'}},
#   'deandre ayton portland': {'team': 'trail blazers',
#    'line': '15.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-112'}},
#   'naz reid': {'team': 'minnesota timberwolves',
#    'line': '11.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-120'}},
#   'anfernee simons portland': {'team': 'trail blazers',
#    'line': '17.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'}},
#   'anthony edwards': {'team': 'minnesota timberwolves',
#    'line': '26.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-118'}},
#   'shaedon sharpe portland': {'team': 'trail blazers',
#    'line': '13.5',
#    'over': {'book_line': '-116'},
#    'under': {'book_line': '-116'}},
#   'toumani camara portland': {'team': 'trail blazers',
#    'line': '9.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-105'}},
#   'scoot henderson portland': {'team': 'trail blazers',
#    'line': '14.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-108'}},
#   'rudy gobert': {'team': 'minnesota timberwolves',
#    'line': '11.5',
#    'over': {'book_line': '-120'},
#    'under': {'book_line': '-112'}},
#   'jerami grant portland': {'team': 'trail blazers',
#    'line': '20.5',
#    'over': {'book_line': '-118'},
#    'under': {'book_line': '-115'}},
#   'jaden mcdaniels': {'team': 'minnesota timberwolves',
#    'line': '10.5',
#    'over': {'book_line': '-122'},
#    'under': {'book_line': '-108'}},
#   'mike conley': {'team': 'minnesota timberwolves',
#    'line': '9.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-106'}}},
#  {'cam reddish': {'team': 'los angeles lakers',
#    'line': '6.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'}},
#   'lebron james': {'team': 'los angeles lakers',
#    'line': '23.5',
#    'over': {'book_line': '-112'},
#    'under': {'book_line': '-118'}},
#   'austin reaves': {'team': 'los angeles lakers',
#    'line': '17.5',
#    'over': {'book_line': '-116'},
#    'under': {'book_line': '-115'}},
#   'gg jackson': {'team': 'memphis grizzlies',
#    'line': '23.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'}},
#   'gabe vincent': {'team': 'los angeles lakers',
#    'line': '4.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'}},
#   'dalton knecht': {'team': 'los angeles lakers',
#    'line': '5.5',
#    'over': {'book_line': '-125'},
#    'under': {'book_line': '-105'}},
#   'dangelo russell': {'team': 'los angeles lakers',
#    'line': '13.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-118'}},
#   'santi aldama': {'team': 'memphis grizzlies',
#    'line': '12.5',
#    'over': {'book_line': '-123'},
#    'under': {'book_line': '-110'}},
#   'rui hachimura': {'team': 'los angeles lakers',
#    'line': '12.5',
#    'over': {'book_line': '-106'},
#    'under': {'book_line': '-122'}},
#   'scotty pippen': {'team': 'memphis grizzlies',
#    'line': '13.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-116'}},
#   'anthony davis': {'team': 'los angeles lakers',
#    'line': '28.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-112'}},
#   'jaren jackson jr': {'team': 'memphis grizzlies',
#    'line': '23.5',
#    'over': {'book_line': '-126'},
#    'under': {'book_line': '-105'}}},
#  {'colby jones': {'team': 'sacramento kings',
#    'line': '11.5',
#    'over': {'book_line': '-114'},
#    'under': {'book_line': '-114'}},
#   'devin booker': {'team': 'phoenix suns',
#    'line': '28.5',
#    'over': {'book_line': '-115'},
#    'under': {'book_line': '-115'}},
#   'kevin huerter': {'team': 'sacramento kings',
#    'line': '9.5',
#    'over': {'book_line': '-119'},
#    'under': {'book_line': '-115'}},
#   'deaaron fox': {'team': 'sacramento kings',
#    'line': '24.5',
#    'over': {'book_line': '-107'},
#    'under': {'book_line': '-125'}},
#   'domantas sabonis': {'team': 'sacramento kings',
#    'line': '19.5',
#    'over': {'book_line': '-110'},
#    'under': {'book_line': '-120'}},
#   'bradley beal': {'team': 'phoenix suns',
#    'line': '21.5',
#    'over': {'book_line': '-109'},
#    'under': {'book_line': '-122'}},
#   'trey lyles': {'team': 'sacramento kings',
#    'line': '7.5',
#    'over': {'book_line': '-113'},
#    'under': {'book_line': '-119'}},
#   'jusuf nurkic': {'team': 'phoenix suns',
#    'line': '11.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-125'}},
#   'keegan murray': {'team': 'sacramento kings',
#    'line': '14.5',
#    'over': {'book_line': '-105'},
#    'under': {'book_line': '-128'}}}]

# %% [markdown]
# df = pd.DataFrame()
# df = df.reindex(range(1000))
# num_rows = len(df)
#
# ##### Calculate the start date
# start_date = datetime.now().date() - timedelta(days = 400)
#
# ##### Create a date range
# date_range = pd.date_range(start=start_date, periods=num_rows)
#
# ##### Add the 'Date' column to your DataFrame
# df['Date'] = date_range
#
# ##### Format the date as MM/DD if you prefer
# df['Date'] = df['Date'].dt.strftime('%Y/%m/%d')

# %%
df = pd.read_csv('prop_table.csv', index_col=0)

# %%
df
# Out:
#            Date  BILAL COULIBALY_line  BILAL COULIBALY_under  \
# 0    2023/10/08                   NaN                    NaN
# 1    2023/10/09                   NaN                    NaN
# 2    2023/10/10                   NaN                    NaN
# 3    2023/10/11                   NaN                    NaN
# 4    2023/10/12                   NaN                    NaN
# ..          ...                   ...                    ...
# 995  2026/06/29                   NaN                    NaN
# 996  2026/06/30                   NaN                    NaN
# 997  2026/07/01                   NaN                    NaN
# 998  2026/07/02                   NaN                    NaN
# 999  2026/07/03                   NaN                    NaN
#
#      BILAL COULIBALY_over  AMEN THOMPSON_line  AMEN THOMPSON_under  \
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     NaN                 NaN                  NaN
# 4                     NaN                 NaN                  NaN
# ..                    ...                 ...                  ...
# 995                   NaN                 NaN                  NaN
# 996                   NaN                 NaN                  NaN
# 997                   NaN                 NaN                  NaN
# 998                   NaN                 NaN                  NaN
# 999                   NaN                 NaN                  NaN
#
#      AMEN THOMPSON_over  JALEN GREEN_line  JALEN GREEN_under  \
# 0                   NaN               NaN                NaN
# 1                   NaN               NaN                NaN
# 2                   NaN               NaN                NaN
# 3                   NaN               NaN                NaN
# 4                   NaN               NaN                NaN
# ..                  ...               ...                ...
# 995                 NaN               NaN                NaN
# 996                 NaN               NaN                NaN
# 997                 NaN               NaN                NaN
# 998                 NaN               NaN                NaN
# 999                 NaN               NaN                NaN
#
#      JALEN GREEN_over  ...  DEAARON FOX_over  DOMANTAS SABONIS_line  \
# 0                 NaN  ...               NaN                    NaN
# 1                 NaN  ...               NaN                    NaN
# 2                 NaN  ...               NaN                    NaN
# 3                 NaN  ...               NaN                    NaN
# 4                 NaN  ...               NaN                    NaN
# ..                ...  ...               ...                    ...
# 995               NaN  ...               NaN                    NaN
# 996               NaN  ...               NaN                    NaN
# 997               NaN  ...               NaN                    NaN
# 998               NaN  ...               NaN                    NaN
# 999               NaN  ...               NaN                    NaN
#
#      DOMANTAS SABONIS_under  DOMANTAS SABONIS_over  TREY LYLES_line  \
# 0                       NaN                    NaN              NaN
# 1                       NaN                    NaN              NaN
# 2                       NaN                    NaN              NaN
# 3                       NaN                    NaN              NaN
# 4                       NaN                    NaN              NaN
# ..                      ...                    ...              ...
# 995                     NaN                    NaN              NaN
# 996                     NaN                    NaN              NaN
# 997                     NaN                    NaN              NaN
# 998                     NaN                    NaN              NaN
# 999                     NaN                    NaN              NaN
#
#      TREY LYLES_under  TREY LYLES_over  KEEGAN MURRAY_line  \
# 0                 NaN              NaN                 NaN
# 1                 NaN              NaN                 NaN
# 2                 NaN              NaN                 NaN
# 3                 NaN              NaN                 NaN
# 4                 NaN              NaN                 NaN
# ..                ...              ...                 ...
# 995               NaN              NaN                 NaN
# 996               NaN              NaN                 NaN
# 997               NaN              NaN                 NaN
# 998               NaN              NaN                 NaN
# 999               NaN              NaN                 NaN
#
#      KEEGAN MURRAY_under  KEEGAN MURRAY_over
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3                    NaN                 NaN
# 4                    NaN                 NaN
# ..                   ...                 ...
# 995                  NaN                 NaN
# 996                  NaN                 NaN
# 997                  NaN                 NaN
# 998                  NaN                 NaN
# 999                  NaN                 NaN
#
# [1000 rows x 403 columns]

# %%
date = datetime.now().date().strftime('%Y/%m/%d') 
for d in game_data:
    for player in d:
        print(player)
        
        # Create a column for the player if it doesn't exist
        if f'{player}_line' not in df.columns:
            df[f'{player}_line'] = np.nan
        if f'{player}_under' not in df.columns:
            df[f'{player}_under'] = np.nan
        if f'{player}_over' not in df.columns:
            df[f'{player}_over'] = np.nan
        
        
        # Find the first NaN value in the player's column
    
        print(date)
        # Assign the new value to the next empty row
        df.loc[df['date'] == date, f'{player}_line'] = d[player]['line']
        df.loc[df['date'] == date, f'{player}_over'] = d[player]['over']['book_line']
        df.loc[df['date'] == date, f'{player}_under'] = d[player]['under']['book_line']
# Out:
# franz wagner
# 2024/11/13
# tyrese haliburton
# 2024/11/13
# bennedict mathurin
# 2024/11/13
# tristan da silva
# 2024/11/13
# goga bitadze
# 2024/11/13
# jalen suggs
# 2024/11/13
# myles turner
# 2024/11/13
# pascal siakam
# 2024/11/13
# luguentz dort
# 2024/11/13
# trey murphy
# 2024/11/13
# shai gilgeousalexander
# 2024/11/13
# jalen williams
# 2024/11/13
# yves missi
# 2024/11/13
# brandon ingram
# 2024/11/13
# zach lavine
# 2024/11/13
# patrick williams
# 2024/11/13
# mikal bridges
# 2024/11/13
# joshua giddey
# 2024/11/13
# ayo dosunmu
# 2024/11/13
# nikola vucevic
# 2024/11/13
# jalen brunson
# 2024/11/13
# og anunoby
# 2024/11/13
# miles mcbride
# 2024/11/13
# josh hart
# 2024/11/13
# coby white
# 2024/11/13
# neemias queta
# 2024/11/13
# jrue holiday
# 2024/11/13
# jaylen brown
# 2024/11/13
# cam thomas
# 2024/11/13
# jayson tatum
# 2024/11/13
# dorian finneysmith
# 2024/11/13
# cameron johnson
# 2024/11/13
# dennis schroder
# 2024/11/13
# nic claxton
# 2024/11/13
# derrick white
# 2024/11/13
# isaac okoro
# 2024/11/13
# evan mobley
# 2024/11/13
# darius garland
# 2024/11/13
# donovan mitchell
# 2024/11/13
# jarrett allen
# 2024/11/13
# brook lopez
# 2024/11/13
# jalen duren
# 2024/11/13
# jaden ivey
# 2024/11/13
# giannis antetokounmpo
# 2024/11/13
# tobias harris
# 2024/11/13
# cade cunningham
# 2024/11/13
# julian champagnie
# 2024/11/13
# stephon castle
# 2024/11/13
# chris paul
# 2024/11/13
# corey kispert
# 2024/11/13
# jordan poole
# 2024/11/13
# alexandre sarr
# 2024/11/13
# kyle kuzma
# 2024/11/13
# bilal coulibaly
# 2024/11/13
# victor wembanyama
# 2024/11/13
# dillon brooks
# 2024/11/13
# terance mann
# 2024/11/13
# alperen sengun
# 2024/11/13
# fred vanvleet
# 2024/11/13
# kai jones
# 2024/11/13
# norman powell
# 2024/11/13
# ivica zubac
# 2024/11/13
# james harden
# 2024/11/13
# jalen green
# 2024/11/13
# jabari smith
# 2024/11/13
# nickeil alexanderwalker
# 2024/11/13
# deandre ayton portland
# 2024/11/13
# naz reid
# 2024/11/13
# anfernee simons portland
# 2024/11/13
# anthony edwards
# 2024/11/13
# shaedon sharpe portland
# 2024/11/13
# toumani camara portland
# 2024/11/13
# scoot henderson portland
# 2024/11/13
# rudy gobert
# 2024/11/13
# jerami grant portland
# 2024/11/13
# jaden mcdaniels
# 2024/11/13
# mike conley
# 2024/11/13
# cam reddish
# 2024/11/13
# lebron james
# 2024/11/13
# austin reaves
# 2024/11/13
# gg jackson
# 2024/11/13
# gabe vincent
# 2024/11/13
# dalton knecht
# 2024/11/13
# dangelo russell
# 2024/11/13
# santi aldama
# 2024/11/13
# rui hachimura
# 2024/11/13
# scotty pippen
# 2024/11/13
# anthony davis
# 2024/11/13
# jaren jackson jr
# 2024/11/13
# colby jones
# 2024/11/13
# devin booker
# 2024/11/13
# kevin huerter
# 2024/11/13
# deaaron fox
# 2024/11/13
# domantas sabonis
# 2024/11/13
# bradley beal
# 2024/11/13
# trey lyles
# 2024/11/13
# jusuf nurkic
# 2024/11/13
# keegan murray
# 2024/11/13

# %%
df = df.loc[:, ~df.columns.duplicated()]
df.shape
# Out:
# (1000, 472)

# %%
df.columns = df.columns.str.lower()
df
# Out:
#            date bilal coulibaly_line bilal coulibaly_under  \
# 0    2023/10/08                  NaN                   NaN
# 1    2023/10/09                  NaN                   NaN
# 2    2023/10/10                  NaN                   NaN
# 3    2023/10/11                  NaN                   NaN
# 4    2023/10/12                  NaN                   NaN
# ..          ...                  ...                   ...
# 995  2026/06/29                  NaN                   NaN
# 996  2026/06/30                  NaN                   NaN
# 997  2026/07/01                  NaN                   NaN
# 998  2026/07/02                  NaN                   NaN
# 999  2026/07/03                  NaN                   NaN
#
#     bilal coulibaly_over  amen thompson_line  amen thompson_under  \
# 0                    NaN                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ..                   ...                 ...                  ...
# 995                  NaN                 NaN                  NaN
# 996                  NaN                 NaN                  NaN
# 997                  NaN                 NaN                  NaN
# 998                  NaN                 NaN                  NaN
# 999                  NaN                 NaN                  NaN
#
#      amen thompson_over jalen green_line jalen green_under jalen green_over  \
# 0                   NaN              NaN               NaN              NaN
# 1                   NaN              NaN               NaN              NaN
# 2                   NaN              NaN               NaN              NaN
# 3                   NaN              NaN               NaN              NaN
# 4                   NaN              NaN               NaN              NaN
# ..                  ...              ...               ...              ...
# 995                 NaN              NaN               NaN              NaN
# 996                 NaN              NaN               NaN              NaN
# 997                 NaN              NaN               NaN              NaN
# 998                 NaN              NaN               NaN              NaN
# 999                 NaN              NaN               NaN              NaN
#
#      ...  dalton knecht_over  dangelo russell_line  dangelo russell_under  \
# 0    ...                 NaN                   NaN                    NaN
# 1    ...                 NaN                   NaN                    NaN
# 2    ...                 NaN                   NaN                    NaN
# 3    ...                 NaN                   NaN                    NaN
# 4    ...                 NaN                   NaN                    NaN
# ..   ...                 ...                   ...                    ...
# 995  ...                 NaN                   NaN                    NaN
# 996  ...                 NaN                   NaN                    NaN
# 997  ...                 NaN                   NaN                    NaN
# 998  ...                 NaN                   NaN                    NaN
# 999  ...                 NaN                   NaN                    NaN
#
#     dangelo russell_over rui hachimura_line rui hachimura_under  \
# 0                    NaN                NaN                 NaN
# 1                    NaN                NaN                 NaN
# 2                    NaN                NaN                 NaN
# 3                    NaN                NaN                 NaN
# 4                    NaN                NaN                 NaN
# ..                   ...                ...                 ...
# 995                  NaN                NaN                 NaN
# 996                  NaN                NaN                 NaN
# 997                  NaN                NaN                 NaN
# 998                  NaN                NaN                 NaN
# 999                  NaN                NaN                 NaN
#
#     rui hachimura_over anthony davis_line anthony davis_under  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
# ..                 ...                ...                 ...
# 995                NaN                NaN                 NaN
# 996                NaN                NaN                 NaN
# 997                NaN                NaN                 NaN
# 998                NaN                NaN                 NaN
# 999                NaN                NaN                 NaN
#
#     anthony davis_over
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 995                NaN
# 996                NaN
# 997                NaN
# 998                NaN
# 999                NaN
#
# [1000 rows x 472 columns]

# %%
df.to_csv('prop_table.csv')

# %%
url = "https://api.sportsgameodds.com/v1/account/usage"

headers = header

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'success': True, 'data': {'keyID': 'b8d294d968b4d0f753d53f4a9e8173952107b1a17338a758b68f98f2ab887092', 'customerID': 'cus_RAwtHswGZQdPPj', 'isActive': True, 'rateLimits': {'per-second': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': 'n/a'}, 'per-minute': {'maxRequestsPerInterval': 10, 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 2, 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': '2024-11-12T19:50:48.097Z'}, 'per-hour': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': 'n/a'}, 'per-day': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 'unlimited', 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 'n/a', 'currentIntervalEndTime': 'n/a'}, 'per-month': {'maxRequestsPerInterval': 'unlimited', 'maxEntitiesPerInterval': 1000, 'currentIntervalRequests': 'n/a', 'currentIntervalEntities': 18, 'currentIntervalEndTime': '2024-12-01T00:00:00.000Z'}}}}

# %%
df['fred vanvleet_line']
# Out:
#     fred vanvleet_line fred vanvleet_line
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ..                 ...                ...
# 995                NaN                NaN
# 996                NaN                NaN
# 997                NaN                NaN
# 998                NaN                NaN
# 999                NaN                NaN
#
# [1000 rows x 2 columns]

# %%
df['franz wagner_line'].loc[df['date'] == '2024/11/13']
# Out:
#     franz wagner_line franz wagner_line
# 402              25.5              25.5
